# %%
# %cd /content/drive/Shared\ drives/CS230 
# %cd google_action_recognition_trial
# Out:
# /content/drive/Shared drives/CS230
# /content/drive/Shared drives/CS230/google_action_recognition_trial

# %%
# This cell is for temporary code consolidation
# %cp ../google_action_recognition_trial/evanet/run* ./evanet/

# %%
import numpy as np
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, Conv3D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D, Reshape
from keras.models import Model
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.utils import plot_model
from keras.initializers import VarianceScaling
import keras.backend as K
from keras.backend import mean
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint

import tensorflow as tf
import matplotlib.pyplot as plt
import h5py
import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
def to_one_hot(labels):
  output = np.zeros(( np.size(labels),6 ))
  label_dict = {'backhand':0,'forehand':1, 'bvolley':2, 'fvolley':3, 'smash':4, 'service':5}
  for n in np.arange(np.size(labels)):
    label = labels[n]
    output[n, label_dict[label]] = 1
  return output

# %%
import csv

def create_data(dataset='train',size=198):
  data = np.zeros([size,1,7,7,2048])
  labels = []
  with open('evanet/data/data_file_1.csv', 'r') as csvfile:
    full_set = csv.reader(csvfile, delimiter=',')
    i = 0
    for row in full_set:
      if row[0] == dataset and i < size:
        features = np.load('evanet/data/1/' + row[2] + '.npy' )
        data[i] = np.mean(features,axis=1,keepdims=True).reshape(1,7,7,2048)
        labels.append(row[1])
        print('Loading ' + row[0] + ' data ' + str(i))
        i+= 1

  with h5py.File(dataset+'_1.hdf5', 'w') as f:
    write_data = f.create_dataset('X', np.shape(data))
    write_data[:] = data 

def load_one_hot_labels(dataset='train',size=198):
  labels = []
  with open('evanet/data/data_file_0.csv', 'r') as csvfile:
    full_set = csv.reader(csvfile, delimiter=',')
    i = 0
    for row in full_set:
      if row[0] == dataset and i < size:  
        labels.append(row[1])
        i+=1
  return to_one_hot(labels)

def load_text_labels(dataset='train',size=198):
  labels = []
  with open('evanet/data/data_file_0.csv', 'r') as csvfile:
    full_set = csv.reader(csvfile, delimiter=',')
    i = 0
    for row in full_set:
      if row[0] == dataset and i < size:  
        labels.append(row[1])
        i+=1
  return labels

def load_data(dataset='train', size=198):
  with h5py.File(dataset+'.hdf5', 'r') as f:
    data = np.array(f['X'])[0:size]
    default_size = data.shape[0]
  labels_one_hot = load_one_hot_labels(dataset=dataset,size=size)

  return data, labels_one_hot


def create_small_dataset(dataset='train',size=20):
  data = np.zeros([size,1,7,7,2048])
  labels = []
  with open('evanet/data/data_file_1.csv', 'r') as csvfile:
    full_set = csv.reader(csvfile, delimiter=',')
    i = 0
    for row in full_set:
      if row[0] == dataset and i < size:
        features = np.load('evanet/data/1/' + row[2] + '.npy' )
        data[i] = np.mean(features,axis=1,keepdims=True).reshape(1,7,7,2048)
        labels.append(row[1])
        print('Loading ' + row[0] + ' data ' + str(i))
        i+= 1
  return data, to_one_hot(labels)

# %%
# create_data(dataset='test',size=192)
# create_data(dataset='validation',size=204)
# create_data(dataset='train',size=1584)

# %%
X, Y = load_data(dataset='validation',size=204)
for i in np.arange(198):
  if np.linalg.norm(X[i]) == 0:
    print('Zero')

# %% [markdown]
# Finding cluster distance

# %%
def centroid(a):
  num_data, dim_data = np.shape(a)
# Out:
#   File "<ipython-input-79-a5f87cc83a50>", line 1
#     def centroid:
#                 ^
# SyntaxError: invalid syntax

# %%
#Dataset 1
labels = ['backhand', 'forehand', 'bvolley', 'fvolley', 'smash', 'service']
L = np.array(load_text_labels(dataset='test', size=192))
Z = np.array([X_test[i].flatten() for i in np.arange(192)])
mean_index = np.zeros((6,100352))
k = 0
for label in labels:
  indices = np.where(L == label)
  Z_label = Z[indices]
  mean_index[k] = np.mean(Z_label, axis=0, keepdims=True)
  k+= 1

for s in np.arange(1, 6):
  for t in np.arange(s):
    distance = np.linalg.norm(mean_index[s] - mean_index[t])/ np.sqrt( np.linalg.norm(mean_index[s]) * np.linalg.norm(mean_index[t]) )
    print('Distance between ' + str(labels[t]) + ' and ' + str(labels[s]) + ': ' + str(distance*100))
# Out:
# Distance between backhand and forehand: 10.271630089085736
# Distance between backhand and bvolley: 24.429467907602987
# Distance between forehand and bvolley: 23.251202825894453
# Distance between backhand and fvolley: 23.74896852421965
# Distance between forehand and fvolley: 19.29877283109069
# Distance between bvolley and fvolley: 25.849116856713383
# Distance between backhand and smash: 26.09256242937721
# Distance between forehand and smash: 20.73303729147233
# Distance between bvolley and smash: 27.348855492469227
# Distance between fvolley and smash: 25.881188912464275
# Distance between backhand and service: 22.950504670408804
# Distance between forehand and service: 19.548779962878367
# Distance between bvolley and service: 32.86433154564611
# Distance between fvolley and service: 31.91019538812589
# Distance between smash and service: 19.727763987404693

# %%
#Dataset 0
P_test, Q_test = load_data(dataset='test',size=192)
labels = ['backhand', 'forehand', 'bvolley', 'fvolley', 'smash', 'service']
L = np.array(load_text_labels(dataset='test', size=192))
Z = np.array([P_test[i].flatten()*1000 for i in np.arange(192)])
mean_index = np.zeros((6,100254))
k = 0
for label in labels:
  indices = np.where(L == label)
  Z_label = Z[indices]
  mean_index[k] = np.mean(Z_label, axis=0, keepdims=True)
  k+= 1
  
for s in np.arange(1, 6):
  for t in np.arange(s):
    distance = np.linalg.norm(mean_index[s] - mean_index[t])/ np.sqrt( np.linalg.norm(mean_index[s]) * np.linalg.norm(mean_index[t])  )
    print('Distance between ' + str(labels[t]) + ' and ' + str(labels[s]) + ': ' + str(distance*100))
# Out:
# Distance between backhand and forehand: 2.8338849712374174
# Distance between backhand and bvolley: 5.335682509921556
# Distance between forehand and bvolley: 4.335228756820503
# Distance between backhand and fvolley: 10.754650265058553
# Distance between forehand and fvolley: 10.372099356679607
# Distance between bvolley and fvolley: 10.082716923180659
# Distance between backhand and smash: 4.780778003354069
# Distance between forehand and smash: 4.471494242799267
# Distance between bvolley and smash: 3.5083392236434077
# Distance between fvolley and smash: 9.335881880347177
# Distance between backhand and service: 9.580303096009878
# Distance between forehand and service: 8.958705408063514
# Distance between bvolley and service: 8.694689267200811
# Distance between fvolley and service: 18.057791226648888
# Distance between smash and service: 9.5953141091814

# %%
X_test.shape
# Out:
# (192, 1, 7, 7, 2048)

# %% [markdown]
# Final version model on dataset 1

# %%
X_train, Y_train = load_data(dataset='train', size=1584)
X_val, Y_val = load_data(dataset='validation',size=204)
X_test, Y_test = load_data(dataset='test',size=192)

# %%
# Train network
dropout_rate=0.3
m=0.01
def model_instance(input_shape):
  X_input = Input(shape = input_shape)
  X = Conv3D(128,kernel_size=(1,7,7), padding='valid',kernel_initializer=VarianceScaling(scale=2.0, mode='fan_in', distribution='normal'))(X_input)
  X = Reshape((128,))(X)
  X = BatchNormalization(momentum=m)(X)
  X = Activation("relu")(X)
  X = Dropout(rate=dropout_rate)(X)
  X = Dense(128)(X)
  X = BatchNormalization(momentum=m)(X)
  X = Activation("relu")(X)
  X = Dropout(rate=dropout_rate)(X)
  X = Dense(64)(X)
  X = BatchNormalization(momentum=m)(X)
  X = Activation("relu")(X)
  X = Dropout(rate=dropout_rate)(X)
  X = Dense(32)(X)
  X = BatchNormalization(momentum=m)(X)
  X = Activation("relu")(X)
  X = Dropout(rate=dropout_rate)(X)
  X = Dense(6)(X)
  preds = Activation("softmax")(X)
  model = Model(inputs=X_input, outputs=preds)
  return model

# %%
model = model_instance(input_shape=(1,7,7,2048))
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 1, 7, 7, 2048)     0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 1, 1, 1, 128)      12845184
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 128)               512
# _________________________________________________________________
# activation_21 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# activation_22 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 64)                256
# _________________________________________________________________
# activation_23 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 32)                128
# _________________________________________________________________
# activation_24 (Activation)   (None, 32)                0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 6)                 198
# _________________________________________________________________
# activation_25 (Activation)   (None, 6)                 0
# =================================================================
# Total params: 12,873,638
# Trainable params: 12,872,934
# Non-trainable params: 704
# _________________________________________________________________

# %%
if not os.path.exists('Checkpoints'):
    os.mkdir('Checkpoints')
opt=Adam()
checkpoint = ModelCheckpoint(os.path.join('Checkpoints','weights_dataset1_dr03_m001_newer.hdf5'), monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='auto')
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.load_weights(os.path.join('Checkpoints','weights_dataset1_dr03_m001_newer.hdf5'))
model.fit(X_train, Y_train, epochs = 500, batch_size=128,callbacks=[checkpoint],validation_data=(X_val,Y_val), shuffle=True, validation_freq=1)
# Out:
# Train on 1584 samples, validate on 204 samples
# Epoch 1/500
# 1584/1584 [==============================] - 3s 2ms/step - loss: 0.0670 - categorical_accuracy: 0.9766 - val_loss: 1.2885 - val_categorical_accuracy: 0.7794
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.77941, saving model to Checkpoints/weights_dataset1_dr03_m001_newer.hdf5
# Epoch 2/500
# 1584/1584 [==============================] - 1s 463us/step - loss: 0.0661 - categorical_accuracy: 0.9792 - val_loss: 1.4585 - val_categorical_accuracy: 0.7794
#
# Epoch 00002: val_categorical_accuracy improved from 0.77941 to 0.77941, saving model to Checkpoints/weights_dataset1_dr03_m001_newer.hdf5
# Epoch 3/500
# 1584/1584 [==============================] - 1s 471us/step - loss: 0.0682 - categorical_accuracy: 0.9766 - val_loss: 1.3636 - val_categorical_accuracy: 0.8186
#
# Epoch 00003: val_categorical_accuracy improved from 0.77941 to 0.81863, saving model to Checkpoints/weights_dataset1_dr03_m001_newer.hdf5
# Epoch 4/500
# 1584/1584 [==============================] - 1s 469us/step - loss: 0.0769 - categorical_accuracy: 0.9747 - val_loss: 1.4604 - val_categorical_accuracy: 0.7402
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.81863
# Epoch 5/500
# 1584/1584 [==============================] - 1s 463us/step - loss: 0.0748 - categorical_accuracy: 0.9817 - val_loss: 1.4264 - val_categorical_accuracy: 0.7794
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.81863
# Epoch 6/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0714 - categorical_accuracy: 0.9773 - val_loss: 1.7159 - val_categorical_accuracy: 0.7255
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.81863
# Epoch 7/500
# 1584/1584 [==============================] - 1s 460us/step - loss: 0.0467 - categorical_accuracy: 0.9830 - val_loss: 1.4537 - val_categorical_accuracy: 0.7892
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.81863
# Epoch 8/500
# 1584/1584 [==============================] - 1s 448us/step - loss: 0.0901 - categorical_accuracy: 0.9754 - val_loss: 1.9688 - val_categorical_accuracy: 0.6765
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.81863
# Epoch 9/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0657 - categorical_accuracy: 0.9785 - val_loss: 1.4421 - val_categorical_accuracy: 0.7549
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.81863
# Epoch 10/500
# 1584/1584 [==============================] - 1s 460us/step - loss: 0.0757 - categorical_accuracy: 0.9817 - val_loss: 1.7833 - val_categorical_accuracy: 0.7843
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.81863
# Epoch 11/500
# 1584/1584 [==============================] - 1s 469us/step - loss: 0.0724 - categorical_accuracy: 0.9779 - val_loss: 1.5759 - val_categorical_accuracy: 0.6961
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.81863
# Epoch 12/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0532 - categorical_accuracy: 0.9823 - val_loss: 1.3295 - val_categorical_accuracy: 0.8039
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.81863
# Epoch 13/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0631 - categorical_accuracy: 0.9785 - val_loss: 1.6516 - val_categorical_accuracy: 0.7549
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.81863
# Epoch 14/500
# 1584/1584 [==============================] - 1s 466us/step - loss: 0.0533 - categorical_accuracy: 0.9798 - val_loss: 1.3236 - val_categorical_accuracy: 0.8039
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.81863
# Epoch 15/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0662 - categorical_accuracy: 0.9817 - val_loss: 1.8853 - val_categorical_accuracy: 0.7402
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.81863
# Epoch 16/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0726 - categorical_accuracy: 0.9760 - val_loss: 1.1731 - val_categorical_accuracy: 0.7892
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.81863
# Epoch 17/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0677 - categorical_accuracy: 0.9830 - val_loss: 1.2702 - val_categorical_accuracy: 0.7990
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.81863
# Epoch 18/500
# 1584/1584 [==============================] - 1s 487us/step - loss: 0.0840 - categorical_accuracy: 0.9766 - val_loss: 1.4520 - val_categorical_accuracy: 0.7941
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.81863
# Epoch 19/500
# 1584/1584 [==============================] - 1s 486us/step - loss: 0.0457 - categorical_accuracy: 0.9874 - val_loss: 1.1852 - val_categorical_accuracy: 0.8088
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.81863
# Epoch 20/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0549 - categorical_accuracy: 0.9848 - val_loss: 1.5377 - val_categorical_accuracy: 0.7941
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.81863
# Epoch 21/500
# 1584/1584 [==============================] - 1s 484us/step - loss: 0.0717 - categorical_accuracy: 0.9798 - val_loss: 1.7540 - val_categorical_accuracy: 0.7353
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.81863
# Epoch 22/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0675 - categorical_accuracy: 0.9747 - val_loss: 1.4437 - val_categorical_accuracy: 0.7647
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.81863
# Epoch 23/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0745 - categorical_accuracy: 0.9798 - val_loss: 1.2428 - val_categorical_accuracy: 0.8039
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.81863
# Epoch 24/500
# 1584/1584 [==============================] - 1s 446us/step - loss: 0.0778 - categorical_accuracy: 0.9747 - val_loss: 1.5969 - val_categorical_accuracy: 0.7696
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.81863
# Epoch 25/500
# 1584/1584 [==============================] - 1s 450us/step - loss: 0.0668 - categorical_accuracy: 0.9779 - val_loss: 1.1840 - val_categorical_accuracy: 0.7794
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.81863
# Epoch 26/500
# 1584/1584 [==============================] - 1s 465us/step - loss: 0.0672 - categorical_accuracy: 0.9785 - val_loss: 1.3090 - val_categorical_accuracy: 0.7843
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.81863
# Epoch 27/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0523 - categorical_accuracy: 0.9811 - val_loss: 1.1865 - val_categorical_accuracy: 0.7892
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.81863
# Epoch 28/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0633 - categorical_accuracy: 0.9836 - val_loss: 1.5210 - val_categorical_accuracy: 0.7500
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.81863
# Epoch 29/500
# 1584/1584 [==============================] - 1s 467us/step - loss: 0.0633 - categorical_accuracy: 0.9754 - val_loss: 1.6108 - val_categorical_accuracy: 0.7500
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.81863
# Epoch 30/500
# 1584/1584 [==============================] - 1s 466us/step - loss: 0.0563 - categorical_accuracy: 0.9792 - val_loss: 1.2384 - val_categorical_accuracy: 0.7696
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.81863
# Epoch 31/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0330 - categorical_accuracy: 0.9886 - val_loss: 1.4704 - val_categorical_accuracy: 0.7843
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.81863
# Epoch 32/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0526 - categorical_accuracy: 0.9785 - val_loss: 1.3608 - val_categorical_accuracy: 0.7598
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.81863
# Epoch 33/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0401 - categorical_accuracy: 0.9886 - val_loss: 1.1894 - val_categorical_accuracy: 0.7794
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.81863
# Epoch 34/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0433 - categorical_accuracy: 0.9880 - val_loss: 1.4931 - val_categorical_accuracy: 0.7696
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.81863
# Epoch 35/500
# 1584/1584 [==============================] - 1s 469us/step - loss: 0.0569 - categorical_accuracy: 0.9836 - val_loss: 1.4532 - val_categorical_accuracy: 0.7843
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.81863
# Epoch 36/500
# 1584/1584 [==============================] - 1s 465us/step - loss: 0.0566 - categorical_accuracy: 0.9867 - val_loss: 1.2391 - val_categorical_accuracy: 0.7745
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.81863
# Epoch 37/500
# 1584/1584 [==============================] - 1s 463us/step - loss: 0.0722 - categorical_accuracy: 0.9785 - val_loss: 1.3418 - val_categorical_accuracy: 0.8039
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.81863
# Epoch 38/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0560 - categorical_accuracy: 0.9811 - val_loss: 1.5371 - val_categorical_accuracy: 0.7255
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.81863
# Epoch 39/500
# 1584/1584 [==============================] - 1s 471us/step - loss: 0.0628 - categorical_accuracy: 0.9798 - val_loss: 1.3707 - val_categorical_accuracy: 0.7843
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.81863
# Epoch 40/500
# 1584/1584 [==============================] - 1s 465us/step - loss: 0.0646 - categorical_accuracy: 0.9760 - val_loss: 1.4696 - val_categorical_accuracy: 0.7892
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.81863
# Epoch 41/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0664 - categorical_accuracy: 0.9830 - val_loss: 1.1933 - val_categorical_accuracy: 0.8137
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.81863
# Epoch 42/500
# 1584/1584 [==============================] - 1s 464us/step - loss: 0.0501 - categorical_accuracy: 0.9855 - val_loss: 1.3653 - val_categorical_accuracy: 0.7647
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.81863
# Epoch 43/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0466 - categorical_accuracy: 0.9899 - val_loss: 1.3013 - val_categorical_accuracy: 0.7598
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.81863
# Epoch 44/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0593 - categorical_accuracy: 0.9817 - val_loss: 1.1065 - val_categorical_accuracy: 0.8088
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.81863
# Epoch 45/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0426 - categorical_accuracy: 0.9874 - val_loss: 1.1215 - val_categorical_accuracy: 0.7647
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.81863
# Epoch 46/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0566 - categorical_accuracy: 0.9842 - val_loss: 0.9844 - val_categorical_accuracy: 0.8284
#
# Epoch 00046: val_categorical_accuracy improved from 0.81863 to 0.82843, saving model to Checkpoints/weights_dataset1_dr03_m001_newer.hdf5
# Epoch 47/500
# 1584/1584 [==============================] - 1s 474us/step - loss: 0.0618 - categorical_accuracy: 0.9842 - val_loss: 1.5163 - val_categorical_accuracy: 0.7500
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.82843
# Epoch 48/500
# 1584/1584 [==============================] - 1s 467us/step - loss: 0.0728 - categorical_accuracy: 0.9760 - val_loss: 1.4060 - val_categorical_accuracy: 0.7745
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.82843
# Epoch 49/500
# 1584/1584 [==============================] - 1s 465us/step - loss: 0.0672 - categorical_accuracy: 0.9754 - val_loss: 1.3033 - val_categorical_accuracy: 0.7941
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.82843
# Epoch 50/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0613 - categorical_accuracy: 0.9792 - val_loss: 1.1240 - val_categorical_accuracy: 0.7794
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.82843
# Epoch 51/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0821 - categorical_accuracy: 0.9811 - val_loss: 1.2587 - val_categorical_accuracy: 0.7549
#
# Epoch 00051: val_categorical_accuracy did not improve from 0.82843
# Epoch 52/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0434 - categorical_accuracy: 0.9836 - val_loss: 1.2829 - val_categorical_accuracy: 0.7647
#
# Epoch 00052: val_categorical_accuracy did not improve from 0.82843
# Epoch 53/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0473 - categorical_accuracy: 0.9842 - val_loss: 1.2405 - val_categorical_accuracy: 0.7647
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.82843
# Epoch 54/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0481 - categorical_accuracy: 0.9823 - val_loss: 1.1951 - val_categorical_accuracy: 0.7745
#
# Epoch 00054: val_categorical_accuracy did not improve from 0.82843
# Epoch 55/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0514 - categorical_accuracy: 0.9773 - val_loss: 1.1206 - val_categorical_accuracy: 0.7990
#
# Epoch 00055: val_categorical_accuracy did not improve from 0.82843
# Epoch 56/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0592 - categorical_accuracy: 0.9855 - val_loss: 1.3635 - val_categorical_accuracy: 0.7941
#
# Epoch 00056: val_categorical_accuracy did not improve from 0.82843
# Epoch 57/500
# 1584/1584 [==============================] - 1s 471us/step - loss: 0.0631 - categorical_accuracy: 0.9773 - val_loss: 1.3622 - val_categorical_accuracy: 0.8088
#
# Epoch 00057: val_categorical_accuracy did not improve from 0.82843
# Epoch 58/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0437 - categorical_accuracy: 0.9867 - val_loss: 1.2898 - val_categorical_accuracy: 0.7794
#
# Epoch 00058: val_categorical_accuracy did not improve from 0.82843
# Epoch 59/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0482 - categorical_accuracy: 0.9861 - val_loss: 1.4231 - val_categorical_accuracy: 0.7598
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.82843
# Epoch 60/500
# 1584/1584 [==============================] - 1s 474us/step - loss: 0.0456 - categorical_accuracy: 0.9842 - val_loss: 1.2299 - val_categorical_accuracy: 0.8039
#
# Epoch 00060: val_categorical_accuracy did not improve from 0.82843
# Epoch 61/500
# 1584/1584 [==============================] - 1s 503us/step - loss: 0.0317 - categorical_accuracy: 0.9880 - val_loss: 1.2635 - val_categorical_accuracy: 0.7941
#
# Epoch 00061: val_categorical_accuracy did not improve from 0.82843
# Epoch 62/500
# 1584/1584 [==============================] - 1s 503us/step - loss: 0.0622 - categorical_accuracy: 0.9817 - val_loss: 1.3514 - val_categorical_accuracy: 0.8039
#
# Epoch 00062: val_categorical_accuracy did not improve from 0.82843
# Epoch 63/500
# 1584/1584 [==============================] - 1s 470us/step - loss: 0.0381 - categorical_accuracy: 0.9855 - val_loss: 1.4869 - val_categorical_accuracy: 0.7794
#
# Epoch 00063: val_categorical_accuracy did not improve from 0.82843
# Epoch 64/500
# 1584/1584 [==============================] - 1s 462us/step - loss: 0.0439 - categorical_accuracy: 0.9880 - val_loss: 1.2989 - val_categorical_accuracy: 0.7794
#
# Epoch 00064: val_categorical_accuracy did not improve from 0.82843
# Epoch 65/500
# 1584/1584 [==============================] - 1s 462us/step - loss: 0.0661 - categorical_accuracy: 0.9842 - val_loss: 2.0213 - val_categorical_accuracy: 0.7157
#
# Epoch 00065: val_categorical_accuracy did not improve from 0.82843
# Epoch 66/500
# 1584/1584 [==============================] - 1s 450us/step - loss: 0.1038 - categorical_accuracy: 0.9710 - val_loss: 1.6515 - val_categorical_accuracy: 0.7647
#
# Epoch 00066: val_categorical_accuracy did not improve from 0.82843
# Epoch 67/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.1298 - categorical_accuracy: 0.9646 - val_loss: 1.4716 - val_categorical_accuracy: 0.7353
#
# Epoch 00067: val_categorical_accuracy did not improve from 0.82843
# Epoch 68/500
# 1584/1584 [==============================] - 1s 479us/step - loss: 0.0989 - categorical_accuracy: 0.9735 - val_loss: 1.1287 - val_categorical_accuracy: 0.8186
#
# Epoch 00068: val_categorical_accuracy did not improve from 0.82843
# Epoch 69/500
# 1584/1584 [==============================] - 1s 467us/step - loss: 0.1096 - categorical_accuracy: 0.9659 - val_loss: 1.4251 - val_categorical_accuracy: 0.7549
#
# Epoch 00069: val_categorical_accuracy did not improve from 0.82843
# Epoch 70/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.1022 - categorical_accuracy: 0.9684 - val_loss: 1.4291 - val_categorical_accuracy: 0.7794
#
# Epoch 00070: val_categorical_accuracy did not improve from 0.82843
# Epoch 71/500
# 1584/1584 [==============================] - 1s 469us/step - loss: 0.0781 - categorical_accuracy: 0.9773 - val_loss: 1.4078 - val_categorical_accuracy: 0.7598
#
# Epoch 00071: val_categorical_accuracy did not improve from 0.82843
# Epoch 72/500
# 1584/1584 [==============================] - 1s 488us/step - loss: 0.0760 - categorical_accuracy: 0.9804 - val_loss: 1.2548 - val_categorical_accuracy: 0.7500
#
# Epoch 00072: val_categorical_accuracy did not improve from 0.82843
# Epoch 73/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0728 - categorical_accuracy: 0.9760 - val_loss: 1.5017 - val_categorical_accuracy: 0.7598
#
# Epoch 00073: val_categorical_accuracy did not improve from 0.82843
# Epoch 74/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0639 - categorical_accuracy: 0.9811 - val_loss: 1.1559 - val_categorical_accuracy: 0.7892
#
# Epoch 00074: val_categorical_accuracy did not improve from 0.82843
# Epoch 75/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0896 - categorical_accuracy: 0.9710 - val_loss: 1.1887 - val_categorical_accuracy: 0.7892
#
# Epoch 00075: val_categorical_accuracy did not improve from 0.82843
# Epoch 76/500
# 1584/1584 [==============================] - 1s 449us/step - loss: 0.0459 - categorical_accuracy: 0.9886 - val_loss: 1.1169 - val_categorical_accuracy: 0.7745
#
# Epoch 00076: val_categorical_accuracy did not improve from 0.82843
# Epoch 77/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0488 - categorical_accuracy: 0.9830 - val_loss: 1.0838 - val_categorical_accuracy: 0.7549
#
# Epoch 00077: val_categorical_accuracy did not improve from 0.82843
# Epoch 78/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0763 - categorical_accuracy: 0.9760 - val_loss: 1.3588 - val_categorical_accuracy: 0.7990
#
# Epoch 00078: val_categorical_accuracy did not improve from 0.82843
# Epoch 79/500
# 1584/1584 [==============================] - 1s 462us/step - loss: 0.0656 - categorical_accuracy: 0.9842 - val_loss: 1.4357 - val_categorical_accuracy: 0.7696
#
# Epoch 00079: val_categorical_accuracy did not improve from 0.82843
# Epoch 80/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0719 - categorical_accuracy: 0.9735 - val_loss: 1.2990 - val_categorical_accuracy: 0.7941
#
# Epoch 00080: val_categorical_accuracy did not improve from 0.82843
# Epoch 81/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0758 - categorical_accuracy: 0.9760 - val_loss: 1.2144 - val_categorical_accuracy: 0.7745
#
# Epoch 00081: val_categorical_accuracy did not improve from 0.82843
# Epoch 82/500
# 1584/1584 [==============================] - 1s 467us/step - loss: 0.0472 - categorical_accuracy: 0.9880 - val_loss: 1.3263 - val_categorical_accuracy: 0.8039
#
# Epoch 00082: val_categorical_accuracy did not improve from 0.82843
# Epoch 83/500
# 1584/1584 [==============================] - 1s 474us/step - loss: 0.0506 - categorical_accuracy: 0.9874 - val_loss: 1.3341 - val_categorical_accuracy: 0.7598
#
# Epoch 00083: val_categorical_accuracy did not improve from 0.82843
# Epoch 84/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0475 - categorical_accuracy: 0.9842 - val_loss: 1.2058 - val_categorical_accuracy: 0.7941
#
# Epoch 00084: val_categorical_accuracy did not improve from 0.82843
# Epoch 85/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0425 - categorical_accuracy: 0.9848 - val_loss: 1.1159 - val_categorical_accuracy: 0.7843
#
# Epoch 00085: val_categorical_accuracy did not improve from 0.82843
# Epoch 86/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0536 - categorical_accuracy: 0.9880 - val_loss: 1.1331 - val_categorical_accuracy: 0.8088
#
# Epoch 00086: val_categorical_accuracy did not improve from 0.82843
# Epoch 87/500
# 1584/1584 [==============================] - 1s 462us/step - loss: 0.0548 - categorical_accuracy: 0.9861 - val_loss: 1.3787 - val_categorical_accuracy: 0.7990
#
# Epoch 00087: val_categorical_accuracy did not improve from 0.82843
# Epoch 88/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0402 - categorical_accuracy: 0.9880 - val_loss: 1.3787 - val_categorical_accuracy: 0.7500
#
# Epoch 00088: val_categorical_accuracy did not improve from 0.82843
# Epoch 89/500
# 1584/1584 [==============================] - 1s 464us/step - loss: 0.0471 - categorical_accuracy: 0.9861 - val_loss: 1.4761 - val_categorical_accuracy: 0.7892
#
# Epoch 00089: val_categorical_accuracy did not improve from 0.82843
# Epoch 90/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0341 - categorical_accuracy: 0.9912 - val_loss: 1.5224 - val_categorical_accuracy: 0.7451
#
# Epoch 00090: val_categorical_accuracy did not improve from 0.82843
# Epoch 91/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0490 - categorical_accuracy: 0.9861 - val_loss: 1.5970 - val_categorical_accuracy: 0.7598
#
# Epoch 00091: val_categorical_accuracy did not improve from 0.82843
# Epoch 92/500
# 1584/1584 [==============================] - 1s 449us/step - loss: 0.0315 - categorical_accuracy: 0.9905 - val_loss: 1.4162 - val_categorical_accuracy: 0.8039
#
# Epoch 00092: val_categorical_accuracy did not improve from 0.82843
# Epoch 93/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0389 - categorical_accuracy: 0.9855 - val_loss: 1.7059 - val_categorical_accuracy: 0.7304
#
# Epoch 00093: val_categorical_accuracy did not improve from 0.82843
# Epoch 94/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0458 - categorical_accuracy: 0.9886 - val_loss: 1.4787 - val_categorical_accuracy: 0.7353
#
# Epoch 00094: val_categorical_accuracy did not improve from 0.82843
# Epoch 95/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0483 - categorical_accuracy: 0.9861 - val_loss: 1.1772 - val_categorical_accuracy: 0.8039
#
# Epoch 00095: val_categorical_accuracy did not improve from 0.82843
# Epoch 96/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0592 - categorical_accuracy: 0.9861 - val_loss: 1.4456 - val_categorical_accuracy: 0.7843
#
# Epoch 00096: val_categorical_accuracy did not improve from 0.82843
# Epoch 97/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0466 - categorical_accuracy: 0.9880 - val_loss: 1.9141 - val_categorical_accuracy: 0.7353
#
# Epoch 00097: val_categorical_accuracy did not improve from 0.82843
# Epoch 98/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0568 - categorical_accuracy: 0.9874 - val_loss: 1.3780 - val_categorical_accuracy: 0.8088
#
# Epoch 00098: val_categorical_accuracy did not improve from 0.82843
# Epoch 99/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0711 - categorical_accuracy: 0.9811 - val_loss: 1.4308 - val_categorical_accuracy: 0.7598
#
# Epoch 00099: val_categorical_accuracy did not improve from 0.82843
# Epoch 100/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0424 - categorical_accuracy: 0.9893 - val_loss: 1.3341 - val_categorical_accuracy: 0.7843
#
# Epoch 00100: val_categorical_accuracy did not improve from 0.82843
# Epoch 101/500
# 1584/1584 [==============================] - 1s 448us/step - loss: 0.0480 - categorical_accuracy: 0.9855 - val_loss: 1.2767 - val_categorical_accuracy: 0.7500
#
# Epoch 00101: val_categorical_accuracy did not improve from 0.82843
# Epoch 102/500
# 1584/1584 [==============================] - 1s 476us/step - loss: 0.0511 - categorical_accuracy: 0.9886 - val_loss: 1.1722 - val_categorical_accuracy: 0.8235
#
# Epoch 00102: val_categorical_accuracy did not improve from 0.82843
# Epoch 103/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0564 - categorical_accuracy: 0.9830 - val_loss: 1.2095 - val_categorical_accuracy: 0.7843
#
# Epoch 00103: val_categorical_accuracy did not improve from 0.82843
# Epoch 104/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0453 - categorical_accuracy: 0.9855 - val_loss: 1.5185 - val_categorical_accuracy: 0.7451
#
# Epoch 00104: val_categorical_accuracy did not improve from 0.82843
# Epoch 105/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0647 - categorical_accuracy: 0.9836 - val_loss: 1.4787 - val_categorical_accuracy: 0.7892
#
# Epoch 00105: val_categorical_accuracy did not improve from 0.82843
# Epoch 106/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0431 - categorical_accuracy: 0.9855 - val_loss: 1.1914 - val_categorical_accuracy: 0.7941
#
# Epoch 00106: val_categorical_accuracy did not improve from 0.82843
# Epoch 107/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0445 - categorical_accuracy: 0.9861 - val_loss: 1.6432 - val_categorical_accuracy: 0.7108
#
# Epoch 00107: val_categorical_accuracy did not improve from 0.82843
# Epoch 108/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0356 - categorical_accuracy: 0.9886 - val_loss: 1.4583 - val_categorical_accuracy: 0.7549
#
# Epoch 00108: val_categorical_accuracy did not improve from 0.82843
# Epoch 109/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0427 - categorical_accuracy: 0.9855 - val_loss: 1.2231 - val_categorical_accuracy: 0.7696
#
# Epoch 00109: val_categorical_accuracy did not improve from 0.82843
# Epoch 110/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0327 - categorical_accuracy: 0.9931 - val_loss: 1.2911 - val_categorical_accuracy: 0.7549
#
# Epoch 00110: val_categorical_accuracy did not improve from 0.82843
# Epoch 111/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0322 - categorical_accuracy: 0.9912 - val_loss: 1.5816 - val_categorical_accuracy: 0.7402
#
# Epoch 00111: val_categorical_accuracy did not improve from 0.82843
# Epoch 112/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0297 - categorical_accuracy: 0.9937 - val_loss: 1.5068 - val_categorical_accuracy: 0.8137
#
# Epoch 00112: val_categorical_accuracy did not improve from 0.82843
# Epoch 113/500
# 1584/1584 [==============================] - 1s 470us/step - loss: 0.0367 - categorical_accuracy: 0.9893 - val_loss: 1.2171 - val_categorical_accuracy: 0.7500
#
# Epoch 00113: val_categorical_accuracy did not improve from 0.82843
# Epoch 114/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0372 - categorical_accuracy: 0.9886 - val_loss: 1.4653 - val_categorical_accuracy: 0.7549
#
# Epoch 00114: val_categorical_accuracy did not improve from 0.82843
# Epoch 115/500
# 1584/1584 [==============================] - 1s 450us/step - loss: 0.0330 - categorical_accuracy: 0.9899 - val_loss: 1.3633 - val_categorical_accuracy: 0.7598
#
# Epoch 00115: val_categorical_accuracy did not improve from 0.82843
# Epoch 116/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0449 - categorical_accuracy: 0.9893 - val_loss: 1.2647 - val_categorical_accuracy: 0.7647
#
# Epoch 00116: val_categorical_accuracy did not improve from 0.82843
# Epoch 117/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0259 - categorical_accuracy: 0.9931 - val_loss: 1.3948 - val_categorical_accuracy: 0.7892
#
# Epoch 00117: val_categorical_accuracy did not improve from 0.82843
# Epoch 118/500
# 1584/1584 [==============================] - 1s 470us/step - loss: 0.0397 - categorical_accuracy: 0.9899 - val_loss: 1.1647 - val_categorical_accuracy: 0.7794
#
# Epoch 00118: val_categorical_accuracy did not improve from 0.82843
# Epoch 119/500
# 1584/1584 [==============================] - 1s 470us/step - loss: 0.0353 - categorical_accuracy: 0.9874 - val_loss: 1.3844 - val_categorical_accuracy: 0.7353
#
# Epoch 00119: val_categorical_accuracy did not improve from 0.82843
# Epoch 120/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0401 - categorical_accuracy: 0.9893 - val_loss: 1.4354 - val_categorical_accuracy: 0.7990
#
# Epoch 00120: val_categorical_accuracy did not improve from 0.82843
# Epoch 121/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0515 - categorical_accuracy: 0.9842 - val_loss: 1.2230 - val_categorical_accuracy: 0.7745
#
# Epoch 00121: val_categorical_accuracy did not improve from 0.82843
# Epoch 122/500
# 1584/1584 [==============================] - 1s 466us/step - loss: 0.0376 - categorical_accuracy: 0.9880 - val_loss: 1.4776 - val_categorical_accuracy: 0.7549
#
# Epoch 00122: val_categorical_accuracy did not improve from 0.82843
# Epoch 123/500
# 1584/1584 [==============================] - 1s 462us/step - loss: 0.0586 - categorical_accuracy: 0.9804 - val_loss: 1.5136 - val_categorical_accuracy: 0.7304
#
# Epoch 00123: val_categorical_accuracy did not improve from 0.82843
# Epoch 124/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0424 - categorical_accuracy: 0.9842 - val_loss: 1.3158 - val_categorical_accuracy: 0.7794
#
# Epoch 00124: val_categorical_accuracy did not improve from 0.82843
# Epoch 125/500
# 1584/1584 [==============================] - 1s 462us/step - loss: 0.0341 - categorical_accuracy: 0.9893 - val_loss: 1.2089 - val_categorical_accuracy: 0.7843
#
# Epoch 00125: val_categorical_accuracy did not improve from 0.82843
# Epoch 126/500
# 1584/1584 [==============================] - 1s 468us/step - loss: 0.0373 - categorical_accuracy: 0.9861 - val_loss: 1.3210 - val_categorical_accuracy: 0.7990
#
# Epoch 00126: val_categorical_accuracy did not improve from 0.82843
# Epoch 127/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0498 - categorical_accuracy: 0.9848 - val_loss: 1.3690 - val_categorical_accuracy: 0.7647
#
# Epoch 00127: val_categorical_accuracy did not improve from 0.82843
# Epoch 128/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0577 - categorical_accuracy: 0.9842 - val_loss: 1.3882 - val_categorical_accuracy: 0.7843
#
# Epoch 00128: val_categorical_accuracy did not improve from 0.82843
# Epoch 129/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0432 - categorical_accuracy: 0.9893 - val_loss: 1.5152 - val_categorical_accuracy: 0.7549
#
# Epoch 00129: val_categorical_accuracy did not improve from 0.82843
# Epoch 130/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0646 - categorical_accuracy: 0.9836 - val_loss: 1.3707 - val_categorical_accuracy: 0.7549
#
# Epoch 00130: val_categorical_accuracy did not improve from 0.82843
# Epoch 131/500
# 1584/1584 [==============================] - 1s 463us/step - loss: 0.0544 - categorical_accuracy: 0.9861 - val_loss: 1.2739 - val_categorical_accuracy: 0.7941
#
# Epoch 00131: val_categorical_accuracy did not improve from 0.82843
# Epoch 132/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0543 - categorical_accuracy: 0.9836 - val_loss: 1.5372 - val_categorical_accuracy: 0.7990
#
# Epoch 00132: val_categorical_accuracy did not improve from 0.82843
# Epoch 133/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0502 - categorical_accuracy: 0.9848 - val_loss: 1.4400 - val_categorical_accuracy: 0.7549
#
# Epoch 00133: val_categorical_accuracy did not improve from 0.82843
# Epoch 134/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0586 - categorical_accuracy: 0.9792 - val_loss: 1.2360 - val_categorical_accuracy: 0.8235
#
# Epoch 00134: val_categorical_accuracy did not improve from 0.82843
# Epoch 135/500
# 1584/1584 [==============================] - 1s 449us/step - loss: 0.0759 - categorical_accuracy: 0.9779 - val_loss: 1.2976 - val_categorical_accuracy: 0.7794
#
# Epoch 00135: val_categorical_accuracy did not improve from 0.82843
# Epoch 136/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0830 - categorical_accuracy: 0.9741 - val_loss: 1.4538 - val_categorical_accuracy: 0.7990
#
# Epoch 00136: val_categorical_accuracy did not improve from 0.82843
# Epoch 137/500
# 1584/1584 [==============================] - 1s 467us/step - loss: 0.0703 - categorical_accuracy: 0.9798 - val_loss: 1.5138 - val_categorical_accuracy: 0.7157
#
# Epoch 00137: val_categorical_accuracy did not improve from 0.82843
# Epoch 138/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0929 - categorical_accuracy: 0.9754 - val_loss: 1.3405 - val_categorical_accuracy: 0.7843
#
# Epoch 00138: val_categorical_accuracy did not improve from 0.82843
# Epoch 139/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0610 - categorical_accuracy: 0.9817 - val_loss: 1.0662 - val_categorical_accuracy: 0.7794
#
# Epoch 00139: val_categorical_accuracy did not improve from 0.82843
# Epoch 140/500
# 1584/1584 [==============================] - 1s 471us/step - loss: 0.0675 - categorical_accuracy: 0.9842 - val_loss: 1.1003 - val_categorical_accuracy: 0.8039
#
# Epoch 00140: val_categorical_accuracy did not improve from 0.82843
# Epoch 141/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0499 - categorical_accuracy: 0.9842 - val_loss: 1.1802 - val_categorical_accuracy: 0.7892
#
# Epoch 00141: val_categorical_accuracy did not improve from 0.82843
# Epoch 142/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0651 - categorical_accuracy: 0.9798 - val_loss: 1.8189 - val_categorical_accuracy: 0.7451
#
# Epoch 00142: val_categorical_accuracy did not improve from 0.82843
# Epoch 143/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0462 - categorical_accuracy: 0.9874 - val_loss: 1.4937 - val_categorical_accuracy: 0.7451
#
# Epoch 00143: val_categorical_accuracy did not improve from 0.82843
# Epoch 144/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0457 - categorical_accuracy: 0.9855 - val_loss: 1.1658 - val_categorical_accuracy: 0.7500
#
# Epoch 00144: val_categorical_accuracy did not improve from 0.82843
# Epoch 145/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0369 - categorical_accuracy: 0.9893 - val_loss: 1.1496 - val_categorical_accuracy: 0.7745
#
# Epoch 00145: val_categorical_accuracy did not improve from 0.82843
# Epoch 146/500
# 1584/1584 [==============================] - 1s 450us/step - loss: 0.0802 - categorical_accuracy: 0.9773 - val_loss: 1.6014 - val_categorical_accuracy: 0.7402
#
# Epoch 00146: val_categorical_accuracy did not improve from 0.82843
# Epoch 147/500
# 1584/1584 [==============================] - 1s 472us/step - loss: 0.0740 - categorical_accuracy: 0.9766 - val_loss: 1.9859 - val_categorical_accuracy: 0.7010
#
# Epoch 00147: val_categorical_accuracy did not improve from 0.82843
# Epoch 148/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0698 - categorical_accuracy: 0.9792 - val_loss: 1.4949 - val_categorical_accuracy: 0.7745
#
# Epoch 00148: val_categorical_accuracy did not improve from 0.82843
# Epoch 149/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0558 - categorical_accuracy: 0.9811 - val_loss: 1.3980 - val_categorical_accuracy: 0.7549
#
# Epoch 00149: val_categorical_accuracy did not improve from 0.82843
# Epoch 150/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0653 - categorical_accuracy: 0.9766 - val_loss: 1.1005 - val_categorical_accuracy: 0.7843
#
# Epoch 00150: val_categorical_accuracy did not improve from 0.82843
# Epoch 151/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0628 - categorical_accuracy: 0.9785 - val_loss: 1.0987 - val_categorical_accuracy: 0.8039
#
# Epoch 00151: val_categorical_accuracy did not improve from 0.82843
# Epoch 152/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0479 - categorical_accuracy: 0.9848 - val_loss: 1.2763 - val_categorical_accuracy: 0.7794
#
# Epoch 00152: val_categorical_accuracy did not improve from 0.82843
# Epoch 153/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0581 - categorical_accuracy: 0.9830 - val_loss: 1.5433 - val_categorical_accuracy: 0.7843
#
# Epoch 00153: val_categorical_accuracy did not improve from 0.82843
# Epoch 154/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0401 - categorical_accuracy: 0.9905 - val_loss: 1.5498 - val_categorical_accuracy: 0.7892
#
# Epoch 00154: val_categorical_accuracy did not improve from 0.82843
# Epoch 155/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0565 - categorical_accuracy: 0.9817 - val_loss: 1.2971 - val_categorical_accuracy: 0.7549
#
# Epoch 00155: val_categorical_accuracy did not improve from 0.82843
# Epoch 156/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0414 - categorical_accuracy: 0.9861 - val_loss: 1.2236 - val_categorical_accuracy: 0.7843
#
# Epoch 00156: val_categorical_accuracy did not improve from 0.82843
# Epoch 157/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0541 - categorical_accuracy: 0.9811 - val_loss: 1.2658 - val_categorical_accuracy: 0.7696
#
# Epoch 00157: val_categorical_accuracy did not improve from 0.82843
# Epoch 158/500
# 1584/1584 [==============================] - 1s 467us/step - loss: 0.0581 - categorical_accuracy: 0.9867 - val_loss: 1.4553 - val_categorical_accuracy: 0.7843
#
# Epoch 00158: val_categorical_accuracy did not improve from 0.82843
# Epoch 159/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0609 - categorical_accuracy: 0.9830 - val_loss: 1.0749 - val_categorical_accuracy: 0.7647
#
# Epoch 00159: val_categorical_accuracy did not improve from 0.82843
# Epoch 160/500
# 1584/1584 [==============================] - 1s 464us/step - loss: 0.0468 - categorical_accuracy: 0.9880 - val_loss: 1.2139 - val_categorical_accuracy: 0.7794
#
# Epoch 00160: val_categorical_accuracy did not improve from 0.82843
# Epoch 161/500
# 1584/1584 [==============================] - 1s 452us/step - loss: 0.0253 - categorical_accuracy: 0.9924 - val_loss: 1.5102 - val_categorical_accuracy: 0.7500
#
# Epoch 00161: val_categorical_accuracy did not improve from 0.82843
# Epoch 162/500
# 1584/1584 [==============================] - 1s 470us/step - loss: 0.0465 - categorical_accuracy: 0.9874 - val_loss: 1.5277 - val_categorical_accuracy: 0.7892
#
# Epoch 00162: val_categorical_accuracy did not improve from 0.82843
# Epoch 163/500
# 1584/1584 [==============================] - 1s 471us/step - loss: 0.0760 - categorical_accuracy: 0.9804 - val_loss: 1.2687 - val_categorical_accuracy: 0.7892
#
# Epoch 00163: val_categorical_accuracy did not improve from 0.82843
# Epoch 164/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0379 - categorical_accuracy: 0.9874 - val_loss: 1.4264 - val_categorical_accuracy: 0.7598
#
# Epoch 00164: val_categorical_accuracy did not improve from 0.82843
# Epoch 165/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0354 - categorical_accuracy: 0.9912 - val_loss: 1.5903 - val_categorical_accuracy: 0.7206
#
# Epoch 00165: val_categorical_accuracy did not improve from 0.82843
# Epoch 166/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0411 - categorical_accuracy: 0.9880 - val_loss: 1.7222 - val_categorical_accuracy: 0.7500
#
# Epoch 00166: val_categorical_accuracy did not improve from 0.82843
# Epoch 167/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0360 - categorical_accuracy: 0.9874 - val_loss: 1.3661 - val_categorical_accuracy: 0.7696
#
# Epoch 00167: val_categorical_accuracy did not improve from 0.82843
# Epoch 168/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0357 - categorical_accuracy: 0.9899 - val_loss: 1.6150 - val_categorical_accuracy: 0.7255
#
# Epoch 00168: val_categorical_accuracy did not improve from 0.82843
# Epoch 169/500
# 1584/1584 [==============================] - 1s 462us/step - loss: 0.0300 - categorical_accuracy: 0.9918 - val_loss: 1.3791 - val_categorical_accuracy: 0.7794
#
# Epoch 00169: val_categorical_accuracy did not improve from 0.82843
# Epoch 170/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0326 - categorical_accuracy: 0.9931 - val_loss: 2.1391 - val_categorical_accuracy: 0.7157
#
# Epoch 00170: val_categorical_accuracy did not improve from 0.82843
# Epoch 171/500
# 1584/1584 [==============================] - 1s 467us/step - loss: 0.0424 - categorical_accuracy: 0.9874 - val_loss: 1.4621 - val_categorical_accuracy: 0.7549
#
# Epoch 00171: val_categorical_accuracy did not improve from 0.82843
# Epoch 172/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0393 - categorical_accuracy: 0.9886 - val_loss: 1.8758 - val_categorical_accuracy: 0.7500
#
# Epoch 00172: val_categorical_accuracy did not improve from 0.82843
# Epoch 173/500
# 1584/1584 [==============================] - 1s 460us/step - loss: 0.0636 - categorical_accuracy: 0.9804 - val_loss: 1.3290 - val_categorical_accuracy: 0.7990
#
# Epoch 00173: val_categorical_accuracy did not improve from 0.82843
# Epoch 174/500
# 1584/1584 [==============================] - 1s 463us/step - loss: 0.0542 - categorical_accuracy: 0.9867 - val_loss: 1.4964 - val_categorical_accuracy: 0.7598
#
# Epoch 00174: val_categorical_accuracy did not improve from 0.82843
# Epoch 175/500
# 1584/1584 [==============================] - 1s 466us/step - loss: 0.0678 - categorical_accuracy: 0.9823 - val_loss: 1.4890 - val_categorical_accuracy: 0.7402
#
# Epoch 00175: val_categorical_accuracy did not improve from 0.82843
# Epoch 176/500
# 1584/1584 [==============================] - 1s 469us/step - loss: 0.0595 - categorical_accuracy: 0.9817 - val_loss: 1.6338 - val_categorical_accuracy: 0.7794
#
# Epoch 00176: val_categorical_accuracy did not improve from 0.82843
# Epoch 177/500
# 1584/1584 [==============================] - 1s 463us/step - loss: 0.0529 - categorical_accuracy: 0.9804 - val_loss: 1.7030 - val_categorical_accuracy: 0.7353
#
# Epoch 00177: val_categorical_accuracy did not improve from 0.82843
# Epoch 178/500
# 1584/1584 [==============================] - 1s 464us/step - loss: 0.0525 - categorical_accuracy: 0.9823 - val_loss: 1.4887 - val_categorical_accuracy: 0.7647
#
# Epoch 00178: val_categorical_accuracy did not improve from 0.82843
# Epoch 179/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0270 - categorical_accuracy: 0.9931 - val_loss: 1.3569 - val_categorical_accuracy: 0.7794
#
# Epoch 00179: val_categorical_accuracy did not improve from 0.82843
# Epoch 180/500
# 1584/1584 [==============================] - 1s 466us/step - loss: 0.0416 - categorical_accuracy: 0.9836 - val_loss: 1.6244 - val_categorical_accuracy: 0.7451
#
# Epoch 00180: val_categorical_accuracy did not improve from 0.82843
# Epoch 181/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0369 - categorical_accuracy: 0.9874 - val_loss: 1.3581 - val_categorical_accuracy: 0.7598
#
# Epoch 00181: val_categorical_accuracy did not improve from 0.82843
# Epoch 182/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0398 - categorical_accuracy: 0.9874 - val_loss: 1.5251 - val_categorical_accuracy: 0.7500
#
# Epoch 00182: val_categorical_accuracy did not improve from 0.82843
# Epoch 183/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0801 - categorical_accuracy: 0.9760 - val_loss: 1.2180 - val_categorical_accuracy: 0.8039
#
# Epoch 00183: val_categorical_accuracy did not improve from 0.82843
# Epoch 184/500
# 1584/1584 [==============================] - 1s 462us/step - loss: 0.0656 - categorical_accuracy: 0.9804 - val_loss: 1.3448 - val_categorical_accuracy: 0.7990
#
# Epoch 00184: val_categorical_accuracy did not improve from 0.82843
# Epoch 185/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0654 - categorical_accuracy: 0.9830 - val_loss: 1.3353 - val_categorical_accuracy: 0.7794
#
# Epoch 00185: val_categorical_accuracy did not improve from 0.82843
# Epoch 186/500
# 1584/1584 [==============================] - 1s 467us/step - loss: 0.0521 - categorical_accuracy: 0.9830 - val_loss: 1.4164 - val_categorical_accuracy: 0.8235
#
# Epoch 00186: val_categorical_accuracy did not improve from 0.82843
# Epoch 187/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0788 - categorical_accuracy: 0.9766 - val_loss: 1.8216 - val_categorical_accuracy: 0.7745
#
# Epoch 00187: val_categorical_accuracy did not improve from 0.82843
# Epoch 188/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0595 - categorical_accuracy: 0.9861 - val_loss: 1.5973 - val_categorical_accuracy: 0.7647
#
# Epoch 00188: val_categorical_accuracy did not improve from 0.82843
# Epoch 189/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0399 - categorical_accuracy: 0.9886 - val_loss: 1.4197 - val_categorical_accuracy: 0.7647
#
# Epoch 00189: val_categorical_accuracy did not improve from 0.82843
# Epoch 190/500
# 1584/1584 [==============================] - 1s 447us/step - loss: 0.0329 - categorical_accuracy: 0.9912 - val_loss: 1.5753 - val_categorical_accuracy: 0.7843
#
# Epoch 00190: val_categorical_accuracy did not improve from 0.82843
# Epoch 191/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0523 - categorical_accuracy: 0.9842 - val_loss: 1.3485 - val_categorical_accuracy: 0.7941
#
# Epoch 00191: val_categorical_accuracy did not improve from 0.82843
# Epoch 192/500
# 1584/1584 [==============================] - 1s 450us/step - loss: 0.0389 - categorical_accuracy: 0.9880 - val_loss: 1.3681 - val_categorical_accuracy: 0.7892
#
# Epoch 00192: val_categorical_accuracy did not improve from 0.82843
# Epoch 193/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0493 - categorical_accuracy: 0.9817 - val_loss: 1.3753 - val_categorical_accuracy: 0.7353
#
# Epoch 00193: val_categorical_accuracy did not improve from 0.82843
# Epoch 194/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0346 - categorical_accuracy: 0.9899 - val_loss: 1.4758 - val_categorical_accuracy: 0.7794
#
# Epoch 00194: val_categorical_accuracy did not improve from 0.82843
# Epoch 195/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0258 - categorical_accuracy: 0.9918 - val_loss: 1.3481 - val_categorical_accuracy: 0.7451
#
# Epoch 00195: val_categorical_accuracy did not improve from 0.82843
# Epoch 196/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0403 - categorical_accuracy: 0.9874 - val_loss: 1.3226 - val_categorical_accuracy: 0.7745
#
# Epoch 00196: val_categorical_accuracy did not improve from 0.82843
# Epoch 197/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0298 - categorical_accuracy: 0.9918 - val_loss: 1.1692 - val_categorical_accuracy: 0.8137
#
# Epoch 00197: val_categorical_accuracy did not improve from 0.82843
# Epoch 198/500
# 1584/1584 [==============================] - 1s 460us/step - loss: 0.0277 - categorical_accuracy: 0.9899 - val_loss: 1.4139 - val_categorical_accuracy: 0.7892
#
# Epoch 00198: val_categorical_accuracy did not improve from 0.82843
# Epoch 199/500
# ...
#
# Epoch 00434: val_categorical_accuracy did not improve from 0.83333
# Epoch 435/500
# 1584/1584 [==============================] - 1s 470us/step - loss: 0.0200 - categorical_accuracy: 0.9949 - val_loss: 1.3119 - val_categorical_accuracy: 0.8088
#
# Epoch 00435: val_categorical_accuracy did not improve from 0.83333
# Epoch 436/500
# 1584/1584 [==============================] - 1s 469us/step - loss: 0.0199 - categorical_accuracy: 0.9924 - val_loss: 1.6035 - val_categorical_accuracy: 0.7745
#
# Epoch 00436: val_categorical_accuracy did not improve from 0.83333
# Epoch 437/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0300 - categorical_accuracy: 0.9905 - val_loss: 1.4762 - val_categorical_accuracy: 0.8039
#
# Epoch 00437: val_categorical_accuracy did not improve from 0.83333
# Epoch 438/500
# 1584/1584 [==============================] - 1s 463us/step - loss: 0.0453 - categorical_accuracy: 0.9899 - val_loss: 1.5138 - val_categorical_accuracy: 0.7843
#
# Epoch 00438: val_categorical_accuracy did not improve from 0.83333
# Epoch 439/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0424 - categorical_accuracy: 0.9880 - val_loss: 1.7888 - val_categorical_accuracy: 0.7794
#
# Epoch 00439: val_categorical_accuracy did not improve from 0.83333
# Epoch 440/500
# 1584/1584 [==============================] - 1s 449us/step - loss: 0.0433 - categorical_accuracy: 0.9905 - val_loss: 2.0556 - val_categorical_accuracy: 0.6814
#
# Epoch 00440: val_categorical_accuracy did not improve from 0.83333
# Epoch 441/500
# 1584/1584 [==============================] - 1s 468us/step - loss: 0.0685 - categorical_accuracy: 0.9817 - val_loss: 1.5890 - val_categorical_accuracy: 0.7941
#
# Epoch 00441: val_categorical_accuracy did not improve from 0.83333
# Epoch 442/500
# 1584/1584 [==============================] - 1s 472us/step - loss: 0.0570 - categorical_accuracy: 0.9823 - val_loss: 1.7357 - val_categorical_accuracy: 0.7108
#
# Epoch 00442: val_categorical_accuracy did not improve from 0.83333
# Epoch 443/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0453 - categorical_accuracy: 0.9848 - val_loss: 1.3960 - val_categorical_accuracy: 0.7941
#
# Epoch 00443: val_categorical_accuracy did not improve from 0.83333
# Epoch 444/500
# 1584/1584 [==============================] - 1s 450us/step - loss: 0.0673 - categorical_accuracy: 0.9830 - val_loss: 1.9702 - val_categorical_accuracy: 0.7157
#
# Epoch 00444: val_categorical_accuracy did not improve from 0.83333
# Epoch 445/500
# 1584/1584 [==============================] - 1s 460us/step - loss: 0.0536 - categorical_accuracy: 0.9830 - val_loss: 2.0225 - val_categorical_accuracy: 0.7010
#
# Epoch 00445: val_categorical_accuracy did not improve from 0.83333
# Epoch 446/500
# 1584/1584 [==============================] - 1s 460us/step - loss: 0.1057 - categorical_accuracy: 0.9678 - val_loss: 1.5712 - val_categorical_accuracy: 0.7696
#
# Epoch 00446: val_categorical_accuracy did not improve from 0.83333
# Epoch 447/500
# 1584/1584 [==============================] - 1s 469us/step - loss: 0.0620 - categorical_accuracy: 0.9779 - val_loss: 1.4509 - val_categorical_accuracy: 0.7745
#
# Epoch 00447: val_categorical_accuracy did not improve from 0.83333
# Epoch 448/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0564 - categorical_accuracy: 0.9773 - val_loss: 1.4954 - val_categorical_accuracy: 0.7549
#
# Epoch 00448: val_categorical_accuracy did not improve from 0.83333
# Epoch 449/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0520 - categorical_accuracy: 0.9861 - val_loss: 1.1653 - val_categorical_accuracy: 0.7990
#
# Epoch 00449: val_categorical_accuracy did not improve from 0.83333
# Epoch 450/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0454 - categorical_accuracy: 0.9842 - val_loss: 1.5075 - val_categorical_accuracy: 0.7549
#
# Epoch 00450: val_categorical_accuracy did not improve from 0.83333
# Epoch 451/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0326 - categorical_accuracy: 0.9893 - val_loss: 1.6277 - val_categorical_accuracy: 0.7353
#
# Epoch 00451: val_categorical_accuracy did not improve from 0.83333
# Epoch 452/500
# 1584/1584 [==============================] - 1s 475us/step - loss: 0.0423 - categorical_accuracy: 0.9855 - val_loss: 1.3645 - val_categorical_accuracy: 0.7794
#
# Epoch 00452: val_categorical_accuracy did not improve from 0.83333
# Epoch 453/500
# 1584/1584 [==============================] - 1s 461us/step - loss: 0.0304 - categorical_accuracy: 0.9912 - val_loss: 1.3554 - val_categorical_accuracy: 0.7941
#
# Epoch 00453: val_categorical_accuracy did not improve from 0.83333
# Epoch 454/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0445 - categorical_accuracy: 0.9905 - val_loss: 1.5141 - val_categorical_accuracy: 0.7843
#
# Epoch 00454: val_categorical_accuracy did not improve from 0.83333
# Epoch 455/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0319 - categorical_accuracy: 0.9918 - val_loss: 1.8851 - val_categorical_accuracy: 0.7696
#
# Epoch 00455: val_categorical_accuracy did not improve from 0.83333
# Epoch 456/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0236 - categorical_accuracy: 0.9956 - val_loss: 1.5078 - val_categorical_accuracy: 0.7843
#
# Epoch 00456: val_categorical_accuracy did not improve from 0.83333
# Epoch 457/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0186 - categorical_accuracy: 0.9943 - val_loss: 1.3733 - val_categorical_accuracy: 0.7892
#
# Epoch 00457: val_categorical_accuracy did not improve from 0.83333
# Epoch 458/500
# 1584/1584 [==============================] - 1s 468us/step - loss: 0.0258 - categorical_accuracy: 0.9931 - val_loss: 1.6964 - val_categorical_accuracy: 0.7794
#
# Epoch 00458: val_categorical_accuracy did not improve from 0.83333
# Epoch 459/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0160 - categorical_accuracy: 0.9949 - val_loss: 1.3268 - val_categorical_accuracy: 0.8039
#
# Epoch 00459: val_categorical_accuracy did not improve from 0.83333
# Epoch 460/500
# 1584/1584 [==============================] - 1s 466us/step - loss: 0.0212 - categorical_accuracy: 0.9924 - val_loss: 1.2204 - val_categorical_accuracy: 0.7990
#
# Epoch 00460: val_categorical_accuracy did not improve from 0.83333
# Epoch 461/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0379 - categorical_accuracy: 0.9880 - val_loss: 1.4199 - val_categorical_accuracy: 0.8186
#
# Epoch 00461: val_categorical_accuracy did not improve from 0.83333
# Epoch 462/500
# 1584/1584 [==============================] - 1s 463us/step - loss: 0.0279 - categorical_accuracy: 0.9918 - val_loss: 1.2543 - val_categorical_accuracy: 0.7745
#
# Epoch 00462: val_categorical_accuracy did not improve from 0.83333
# Epoch 463/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0330 - categorical_accuracy: 0.9905 - val_loss: 1.3490 - val_categorical_accuracy: 0.7745
#
# Epoch 00463: val_categorical_accuracy did not improve from 0.83333
# Epoch 464/500
# 1584/1584 [==============================] - 1s 474us/step - loss: 0.0346 - categorical_accuracy: 0.9899 - val_loss: 1.4635 - val_categorical_accuracy: 0.7843
#
# Epoch 00464: val_categorical_accuracy did not improve from 0.83333
# Epoch 465/500
# 1584/1584 [==============================] - 1s 469us/step - loss: 0.0250 - categorical_accuracy: 0.9899 - val_loss: 1.4076 - val_categorical_accuracy: 0.7892
#
# Epoch 00465: val_categorical_accuracy did not improve from 0.83333
# Epoch 466/500
# 1584/1584 [==============================] - 1s 462us/step - loss: 0.0363 - categorical_accuracy: 0.9905 - val_loss: 1.4702 - val_categorical_accuracy: 0.7696
#
# Epoch 00466: val_categorical_accuracy did not improve from 0.83333
# Epoch 467/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0326 - categorical_accuracy: 0.9893 - val_loss: 1.4909 - val_categorical_accuracy: 0.7843
#
# Epoch 00467: val_categorical_accuracy did not improve from 0.83333
# Epoch 468/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0434 - categorical_accuracy: 0.9880 - val_loss: 1.4307 - val_categorical_accuracy: 0.7794
#
# Epoch 00468: val_categorical_accuracy did not improve from 0.83333
# Epoch 469/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0366 - categorical_accuracy: 0.9905 - val_loss: 1.5002 - val_categorical_accuracy: 0.8088
#
# Epoch 00469: val_categorical_accuracy did not improve from 0.83333
# Epoch 470/500
# 1584/1584 [==============================] - 1s 460us/step - loss: 0.0348 - categorical_accuracy: 0.9918 - val_loss: 1.3036 - val_categorical_accuracy: 0.7892
#
# Epoch 00470: val_categorical_accuracy did not improve from 0.83333
# Epoch 471/500
# 1584/1584 [==============================] - 1s 481us/step - loss: 0.0236 - categorical_accuracy: 0.9937 - val_loss: 1.2486 - val_categorical_accuracy: 0.7696
#
# Epoch 00471: val_categorical_accuracy did not improve from 0.83333
# Epoch 472/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0174 - categorical_accuracy: 0.9931 - val_loss: 1.5360 - val_categorical_accuracy: 0.7745
#
# Epoch 00472: val_categorical_accuracy did not improve from 0.83333
# Epoch 473/500
# 1584/1584 [==============================] - 1s 459us/step - loss: 0.0226 - categorical_accuracy: 0.9937 - val_loss: 1.1669 - val_categorical_accuracy: 0.7843
#
# Epoch 00473: val_categorical_accuracy did not improve from 0.83333
# Epoch 474/500
# 1584/1584 [==============================] - 1s 449us/step - loss: 0.0300 - categorical_accuracy: 0.9931 - val_loss: 1.3118 - val_categorical_accuracy: 0.7941
#
# Epoch 00474: val_categorical_accuracy did not improve from 0.83333
# Epoch 475/500
# 1584/1584 [==============================] - 1s 453us/step - loss: 0.0196 - categorical_accuracy: 0.9943 - val_loss: 1.2007 - val_categorical_accuracy: 0.7892
#
# Epoch 00475: val_categorical_accuracy did not improve from 0.83333
# Epoch 476/500
# 1584/1584 [==============================] - 1s 460us/step - loss: 0.0182 - categorical_accuracy: 0.9924 - val_loss: 1.5625 - val_categorical_accuracy: 0.7696
#
# Epoch 00476: val_categorical_accuracy did not improve from 0.83333
# Epoch 477/500
# 1584/1584 [==============================] - 1s 466us/step - loss: 0.0188 - categorical_accuracy: 0.9949 - val_loss: 1.7137 - val_categorical_accuracy: 0.7353
#
# Epoch 00477: val_categorical_accuracy did not improve from 0.83333
# Epoch 478/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0197 - categorical_accuracy: 0.9956 - val_loss: 1.5129 - val_categorical_accuracy: 0.7892
#
# Epoch 00478: val_categorical_accuracy did not improve from 0.83333
# Epoch 479/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0430 - categorical_accuracy: 0.9893 - val_loss: 1.9845 - val_categorical_accuracy: 0.7696
#
# Epoch 00479: val_categorical_accuracy did not improve from 0.83333
# Epoch 480/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0365 - categorical_accuracy: 0.9893 - val_loss: 1.4724 - val_categorical_accuracy: 0.7598
#
# Epoch 00480: val_categorical_accuracy did not improve from 0.83333
# Epoch 481/500
# 1584/1584 [==============================] - 1s 447us/step - loss: 0.0359 - categorical_accuracy: 0.9893 - val_loss: 1.7676 - val_categorical_accuracy: 0.7549
#
# Epoch 00481: val_categorical_accuracy did not improve from 0.83333
# Epoch 482/500
# 1584/1584 [==============================] - 1s 448us/step - loss: 0.0324 - categorical_accuracy: 0.9867 - val_loss: 1.5310 - val_categorical_accuracy: 0.7843
#
# Epoch 00482: val_categorical_accuracy did not improve from 0.83333
# Epoch 483/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0437 - categorical_accuracy: 0.9893 - val_loss: 1.7639 - val_categorical_accuracy: 0.7598
#
# Epoch 00483: val_categorical_accuracy did not improve from 0.83333
# Epoch 484/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0288 - categorical_accuracy: 0.9924 - val_loss: 1.4489 - val_categorical_accuracy: 0.7696
#
# Epoch 00484: val_categorical_accuracy did not improve from 0.83333
# Epoch 485/500
# 1584/1584 [==============================] - 1s 449us/step - loss: 0.0631 - categorical_accuracy: 0.9867 - val_loss: 1.7453 - val_categorical_accuracy: 0.7696
#
# Epoch 00485: val_categorical_accuracy did not improve from 0.83333
# Epoch 486/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0256 - categorical_accuracy: 0.9924 - val_loss: 1.5765 - val_categorical_accuracy: 0.7696
#
# Epoch 00486: val_categorical_accuracy did not improve from 0.83333
# Epoch 487/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0375 - categorical_accuracy: 0.9886 - val_loss: 1.5798 - val_categorical_accuracy: 0.7745
#
# Epoch 00487: val_categorical_accuracy did not improve from 0.83333
# Epoch 488/500
# 1584/1584 [==============================] - 1s 470us/step - loss: 0.0204 - categorical_accuracy: 0.9937 - val_loss: 1.8411 - val_categorical_accuracy: 0.7647
#
# Epoch 00488: val_categorical_accuracy did not improve from 0.83333
# Epoch 489/500
# 1584/1584 [==============================] - 1s 454us/step - loss: 0.0543 - categorical_accuracy: 0.9880 - val_loss: 1.3353 - val_categorical_accuracy: 0.7696
#
# Epoch 00489: val_categorical_accuracy did not improve from 0.83333
# Epoch 490/500
# 1584/1584 [==============================] - 1s 466us/step - loss: 0.0312 - categorical_accuracy: 0.9937 - val_loss: 1.2888 - val_categorical_accuracy: 0.7549
#
# Epoch 00490: val_categorical_accuracy did not improve from 0.83333
# Epoch 491/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0450 - categorical_accuracy: 0.9861 - val_loss: 1.5222 - val_categorical_accuracy: 0.7647
#
# Epoch 00491: val_categorical_accuracy did not improve from 0.83333
# Epoch 492/500
# 1584/1584 [==============================] - 1s 455us/step - loss: 0.0486 - categorical_accuracy: 0.9874 - val_loss: 1.9301 - val_categorical_accuracy: 0.7647
#
# Epoch 00492: val_categorical_accuracy did not improve from 0.83333
# Epoch 493/500
# 1584/1584 [==============================] - 1s 457us/step - loss: 0.0505 - categorical_accuracy: 0.9880 - val_loss: 1.1983 - val_categorical_accuracy: 0.7794
#
# Epoch 00493: val_categorical_accuracy did not improve from 0.83333
# Epoch 494/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0525 - categorical_accuracy: 0.9880 - val_loss: 1.4276 - val_categorical_accuracy: 0.7941
#
# Epoch 00494: val_categorical_accuracy did not improve from 0.83333
# Epoch 495/500
# 1584/1584 [==============================] - 1s 451us/step - loss: 0.0553 - categorical_accuracy: 0.9861 - val_loss: 1.6178 - val_categorical_accuracy: 0.7255
#
# Epoch 00495: val_categorical_accuracy did not improve from 0.83333
# Epoch 496/500
# 1584/1584 [==============================] - 1s 475us/step - loss: 0.0410 - categorical_accuracy: 0.9899 - val_loss: 1.6614 - val_categorical_accuracy: 0.7696
#
# Epoch 00496: val_categorical_accuracy did not improve from 0.83333
# Epoch 497/500
# 1584/1584 [==============================] - 1s 464us/step - loss: 0.0439 - categorical_accuracy: 0.9867 - val_loss: 1.4888 - val_categorical_accuracy: 0.7892
#
# Epoch 00497: val_categorical_accuracy did not improve from 0.83333
# Epoch 498/500
# 1584/1584 [==============================] - 1s 458us/step - loss: 0.0464 - categorical_accuracy: 0.9848 - val_loss: 1.4975 - val_categorical_accuracy: 0.7843
#
# Epoch 00498: val_categorical_accuracy did not improve from 0.83333
# Epoch 499/500
# 1584/1584 [==============================] - 1s 466us/step - loss: 0.0216 - categorical_accuracy: 0.9937 - val_loss: 1.5533 - val_categorical_accuracy: 0.7843
#
# Epoch 00499: val_categorical_accuracy did not improve from 0.83333
# Epoch 500/500
# 1584/1584 [==============================] - 1s 456us/step - loss: 0.0277 - categorical_accuracy: 0.9931 - val_loss: 1.8782 - val_categorical_accuracy: 0.7745
#
# Epoch 00500: val_categorical_accuracy did not improve from 0.83333

# %%
opt=Adam()
model.load_weights(os.path.join('Checkpoints','weights_dataset1_dr03_m001_newer.hdf5'))
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.evaluate(X_train,Y_train))
print(model.evaluate(X_val,Y_val))
print(model.evaluate(X_test,Y_test))
# Out:
# 1584/1584 [==============================] - 1s 556us/step
# [0.004280151370554137, 1.0]
# 204/204 [==============================] - 0s 269us/step
# [1.0596045840020274, 0.8333333333333334]
# 192/192 [==============================] - 0s 247us/step
# [1.6362652809669573, 0.78125]

# %%
Y_probs=model.predict(X_test)
Y_pred=np.argmax(Y_probs,axis=1)
Y_test_cat=np.argmax(Y_test,axis=1)
target_names = ['backhand', 'forehand', 'bvolley', 'fvolley', 
                   'smash', 'service']
from sklearn.metrics import classification_report, confusion_matrix
print (classification_report(Y_test_cat, Y_pred, target_names=target_names))
conf_matrix = confusion_matrix(Y_test_cat, Y_pred)
import seaborn as sns
import pandas as pd
sns.set(font_scale=1.7)
df_cm = pd.DataFrame(conf_matrix, index = [i for i in target_names],
                  columns = [i for i in target_names])
plt.figure(figsize = (8,5))
ax = sns.heatmap(df_cm, annot=True)
ax.set_xlabel('Predicted Class', fontsize=18, labelpad=20)
ax.set_ylabel('True Class', fontsize=18, rotation=0, labelpad=55)
plt.savefig('confusion_matrix_1.jpg', bbox_inches = 'tight')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#     backhand       0.90      0.75      0.82        48
#     forehand       0.72      0.88      0.79        48
#      bvolley       0.79      0.94      0.86        16
#      fvolley       0.73      0.50      0.59        16
#        smash       0.71      0.31      0.43        16
#      service       0.81      0.96      0.88        48
#
#     accuracy                           0.79       192
#    macro avg       0.78      0.72      0.73       192
# weighted avg       0.79      0.79      0.78       192
