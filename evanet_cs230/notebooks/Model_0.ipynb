# %%
# %cd /content/drive/Shared\ drives/CS230 
# %cd google_action_recognition_trial
# Out:
# /content/drive/Shared drives/CS230
# /content/drive/Shared drives/CS230/google_action_recognition_trial

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, Conv3D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D, Reshape,AveragePooling3D, Bidirectional, LSTM, TimeDistributed, Lambda, Concatenate
from keras.models import Model
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.utils import plot_model
from keras.initializers import VarianceScaling
from keras.backend import mean
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint

import keras.backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
import h5py
import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
#helper fn for one hot label generation
def to_one_hot(labels):
  output = np.zeros(( np.size(labels),6 ))
  label_dict = {'backhand':0,'forehand':1, 'bvolley':2, 'fvolley':3, 'smash':4, 'service':5}
  for n in np.arange(np.size(labels)):
    label = labels[n]
    output[n, label_dict[label]] = 1
  return output

# %%
#helper functions
import csv

def create_data(dataset='train',size=20):
  data = np.zeros([size,1,7,7,2046])
  labels = []
  with open('evanet/data/data_file_0.csv', 'r') as csvfile:
    full_set = csv.reader(csvfile, delimiter=',')
    i = 0
    for row in full_set:
      if row[0] == dataset and i < size:
        features = np.load('evanet/data/0/' + row[2] + '.npy' )
        data[i] = np.mean(features,axis=1,keepdims=True).reshape(1,7,7,2046)
        labels.append(row[1])
        print('Loading ' + row[0] + ' data ' + str(i))
        i+= 1

  with h5py.File(dataset+'.hdf5', 'w') as f:
    write_data = f.create_dataset('X', np.shape(data))
    write_data[:] = data 

def load_labels(dataset='train',size=20):
  labels = []
  with open('evanet/data/data_file_0.csv', 'r') as csvfile:
    full_set = csv.reader(csvfile, delimiter=',')
    i = 0
    for row in full_set:
      if row[0] == dataset and i < size:  
        labels.append(row[1])
        i+=1
  return to_one_hot(labels)

def load_data(size_whole,dataset='train'):
  with h5py.File(dataset+'.hdf5', 'r') as f:
    data = np.array(f['X'])
    size = data.shape[0]
  labels_one_hot = load_labels(dataset=dataset,size=size)

  return data[:size_whole], labels_one_hot[:size_whole]


def create_small_dataset(dataset='train',size=20):
  data = np.zeros([size,1,7,7,2046])
  labels = []
  with open('evanet/data/data_file_0.csv', 'r') as csvfile:
    full_set = csv.reader(csvfile, delimiter=',')
    i = 0
    for row in full_set:
      if row[0] == dataset and i < size:
        features = np.load('evanet/data/0/' + row[2] + '.npy' )
        data[i] = np.mean(features,axis=1,keepdims=True).reshape(1,7,7,2046)
        labels.append(row[1])
        print('Loading ' + row[0] + ' data ' + str(i))
        i+= 1
  return data, to_one_hot(labels)

# %%
#X_train_1, Y_train_1 = create_small_dataset(dataset='train', size=20)
X_train, Y_train = load_data(size_whole=1584,dataset='train')

# %%
X_val, Y_val = load_data(size_whole=204,dataset='validation')
X_test, Y_test = load_data(size_whole=192,dataset='test')

# %%
X_test.shape
# Out:
# (192, 1, 7, 7, 2046)

# %% [markdown]
# Deep Model

# %%
# Train network
dropout_rate=0.3
m=0.1
def model_instance(input_shape):
  X_input = Input(shape = input_shape)
  X = Conv3D(128,kernel_size=(1,7,7), padding='valid',kernel_initializer=VarianceScaling(scale=2.0, mode='fan_in', distribution='normal'))(X_input)
  #,kernel_initializer=VarianceScaling(scale=2.0, mode='fan_in', distribution='normal')  
  X = Reshape((128,))(X)
  X = BatchNormalization(momentum=m)(X)
  X = Activation("relu")(X)
  X = Dropout(rate=dropout_rate)(X)
  X = Dense(128)(X)
  X = BatchNormalization(momentum=m)(X)
  X = Activation("relu")(X)
  X = Dropout(rate=dropout_rate)(X)
  X = Dense(64)(X)
  X = BatchNormalization(momentum=m)(X)
  X = Activation("relu")(X)
  X = Dropout(rate=dropout_rate)(X)
  X = Dense(32)(X)
  X = BatchNormalization(momentum=m)(X)
  X = Activation("relu")(X)
  X = Dropout(rate=dropout_rate)(X)
  X = Dense(6)(X)
  preds = Activation("softmax")(X)
  model = Model(inputs=X_input, outputs=preds)
  return model

# %%
model = model_instance(input_shape=(1,7,7,2046))
model.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        (None, 1, 7, 7, 2046)     0
# _________________________________________________________________
# conv3d_16 (Conv3D)           (None, 1, 1, 1, 128)      12832640
# _________________________________________________________________
# reshape_16 (Reshape)         (None, 128)               0
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 128)               512
# _________________________________________________________________
# activation_76 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_61 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 128)               512
# _________________________________________________________________
# activation_77 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_62 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 64)                256
# _________________________________________________________________
# activation_78 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 32)                128
# _________________________________________________________________
# activation_79 (Activation)   (None, 32)                0
# _________________________________________________________________
# dropout_64 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_64 (Dense)             (None, 6)                 198
# _________________________________________________________________
# activation_80 (Activation)   (None, 6)                 0
# =================================================================
# Total params: 12,861,094
# Trainable params: 12,860,390
# Non-trainable params: 704
# _________________________________________________________________

# %%
if not os.path.exists('Checkpoints'):
    os.mkdir('Checkpoints')
opt=Adam()
checkpoint = ModelCheckpoint(os.path.join('Checkpoints','weights_model_0_dr03_m5_new.hdf5'), monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='auto')
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, Y_train, epochs = 1000, batch_size=128,callbacks=[checkpoint],validation_data=(X_val,Y_val), shuffle=True, validation_freq=1)
# Out:
# Train on 1584 samples, validate on 204 samples
# Epoch 1/1000
# 1584/1584 [==============================] - 4s 3ms/step - loss: 2.1285 - categorical_accuracy: 0.1515 - val_loss: 1.7521 - val_categorical_accuracy: 0.2451
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.24510, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 2/1000
# 1584/1584 [==============================] - 1s 416us/step - loss: 1.9615 - categorical_accuracy: 0.1944 - val_loss: 1.7358 - val_categorical_accuracy: 0.2696
#
# Epoch 00002: val_categorical_accuracy improved from 0.24510 to 0.26961, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 3/1000
# 1584/1584 [==============================] - 1s 400us/step - loss: 1.8672 - categorical_accuracy: 0.2292 - val_loss: 1.6968 - val_categorical_accuracy: 0.2892
#
# Epoch 00003: val_categorical_accuracy improved from 0.26961 to 0.28922, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 4/1000
# 1584/1584 [==============================] - 1s 367us/step - loss: 1.8788 - categorical_accuracy: 0.2229 - val_loss: 1.6448 - val_categorical_accuracy: 0.3333
#
# Epoch 00004: val_categorical_accuracy improved from 0.28922 to 0.33333, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 5/1000
# 1584/1584 [==============================] - 1s 411us/step - loss: 1.7539 - categorical_accuracy: 0.2557 - val_loss: 1.6458 - val_categorical_accuracy: 0.2892
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.33333
# Epoch 6/1000
# 1584/1584 [==============================] - 1s 369us/step - loss: 1.7418 - categorical_accuracy: 0.2645 - val_loss: 1.6269 - val_categorical_accuracy: 0.3088
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.33333
# Epoch 7/1000
# 1584/1584 [==============================] - 1s 368us/step - loss: 1.7398 - categorical_accuracy: 0.2639 - val_loss: 1.6255 - val_categorical_accuracy: 0.3235
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.33333
# Epoch 8/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 1.7334 - categorical_accuracy: 0.2778 - val_loss: 1.6160 - val_categorical_accuracy: 0.3333
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.33333
# Epoch 9/1000
# 1584/1584 [==============================] - 1s 395us/step - loss: 1.7134 - categorical_accuracy: 0.2986 - val_loss: 1.6200 - val_categorical_accuracy: 0.3235
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.33333
# Epoch 10/1000
# 1584/1584 [==============================] - 1s 354us/step - loss: 1.6984 - categorical_accuracy: 0.2955 - val_loss: 1.6014 - val_categorical_accuracy: 0.3088
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.33333
# Epoch 11/1000
# 1584/1584 [==============================] - 1s 374us/step - loss: 1.6873 - categorical_accuracy: 0.3005 - val_loss: 1.6163 - val_categorical_accuracy: 0.3333
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.33333
# Epoch 12/1000
# 1584/1584 [==============================] - 1s 371us/step - loss: 1.6501 - categorical_accuracy: 0.3049 - val_loss: 1.6055 - val_categorical_accuracy: 0.3725
#
# Epoch 00012: val_categorical_accuracy improved from 0.33333 to 0.37255, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 13/1000
# 1584/1584 [==============================] - 1s 423us/step - loss: 1.6711 - categorical_accuracy: 0.2885 - val_loss: 1.6034 - val_categorical_accuracy: 0.3578
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.37255
# Epoch 14/1000
# 1584/1584 [==============================] - 1s 393us/step - loss: 1.6657 - categorical_accuracy: 0.2866 - val_loss: 1.5871 - val_categorical_accuracy: 0.3676
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.37255
# Epoch 15/1000
# 1584/1584 [==============================] - 1s 417us/step - loss: 1.6684 - categorical_accuracy: 0.2885 - val_loss: 1.5762 - val_categorical_accuracy: 0.3676
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.37255
# Epoch 16/1000
# 1584/1584 [==============================] - 1s 444us/step - loss: 1.6576 - categorical_accuracy: 0.3100 - val_loss: 1.5758 - val_categorical_accuracy: 0.3725
#
# Epoch 00016: val_categorical_accuracy improved from 0.37255 to 0.37255, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 17/1000
# 1584/1584 [==============================] - 1s 444us/step - loss: 1.6373 - categorical_accuracy: 0.3018 - val_loss: 1.5707 - val_categorical_accuracy: 0.3480
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.37255
# Epoch 18/1000
# 1584/1584 [==============================] - 1s 428us/step - loss: 1.6558 - categorical_accuracy: 0.2992 - val_loss: 1.5838 - val_categorical_accuracy: 0.3480
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.37255
# Epoch 19/1000
# 1584/1584 [==============================] - 1s 412us/step - loss: 1.6190 - categorical_accuracy: 0.3226 - val_loss: 1.5918 - val_categorical_accuracy: 0.3431
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.37255
# Epoch 20/1000
# 1584/1584 [==============================] - 1s 429us/step - loss: 1.6233 - categorical_accuracy: 0.3245 - val_loss: 1.5915 - val_categorical_accuracy: 0.3627
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.37255
# Epoch 21/1000
# 1584/1584 [==============================] - 1s 395us/step - loss: 1.6188 - categorical_accuracy: 0.3207 - val_loss: 1.5776 - val_categorical_accuracy: 0.3529
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.37255
# Epoch 22/1000
# 1584/1584 [==============================] - 1s 421us/step - loss: 1.6120 - categorical_accuracy: 0.3201 - val_loss: 1.5661 - val_categorical_accuracy: 0.3775
#
# Epoch 00022: val_categorical_accuracy improved from 0.37255 to 0.37745, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 23/1000
# 1584/1584 [==============================] - 1s 388us/step - loss: 1.6096 - categorical_accuracy: 0.3239 - val_loss: 1.5779 - val_categorical_accuracy: 0.3431
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.37745
# Epoch 24/1000
# 1584/1584 [==============================] - 1s 400us/step - loss: 1.6168 - categorical_accuracy: 0.3283 - val_loss: 1.5751 - val_categorical_accuracy: 0.3480
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.37745
# Epoch 25/1000
# 1584/1584 [==============================] - 1s 381us/step - loss: 1.5979 - categorical_accuracy: 0.3239 - val_loss: 1.5531 - val_categorical_accuracy: 0.3676
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.37745
# Epoch 26/1000
# 1584/1584 [==============================] - 1s 401us/step - loss: 1.5759 - categorical_accuracy: 0.3295 - val_loss: 1.5888 - val_categorical_accuracy: 0.3431
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.37745
# Epoch 27/1000
# 1584/1584 [==============================] - 1s 378us/step - loss: 1.5941 - categorical_accuracy: 0.3422 - val_loss: 1.5530 - val_categorical_accuracy: 0.3627
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.37745
# Epoch 28/1000
# 1584/1584 [==============================] - 1s 398us/step - loss: 1.5912 - categorical_accuracy: 0.3466 - val_loss: 1.5609 - val_categorical_accuracy: 0.3725
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.37745
# Epoch 29/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 1.5796 - categorical_accuracy: 0.3447 - val_loss: 1.5509 - val_categorical_accuracy: 0.3529
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.37745
# Epoch 30/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 1.5735 - categorical_accuracy: 0.3396 - val_loss: 1.5598 - val_categorical_accuracy: 0.3480
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.37745
# Epoch 31/1000
# 1584/1584 [==============================] - 1s 412us/step - loss: 1.5584 - categorical_accuracy: 0.3643 - val_loss: 1.5631 - val_categorical_accuracy: 0.3676
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.37745
# Epoch 32/1000
# 1584/1584 [==============================] - 1s 373us/step - loss: 1.5725 - categorical_accuracy: 0.3422 - val_loss: 1.5449 - val_categorical_accuracy: 0.3676
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.37745
# Epoch 33/1000
# 1584/1584 [==============================] - 1s 377us/step - loss: 1.5526 - categorical_accuracy: 0.3428 - val_loss: 1.5402 - val_categorical_accuracy: 0.3529
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.37745
# Epoch 34/1000
# 1584/1584 [==============================] - 1s 381us/step - loss: 1.5486 - categorical_accuracy: 0.3624 - val_loss: 1.5866 - val_categorical_accuracy: 0.3039
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.37745
# Epoch 35/1000
# 1584/1584 [==============================] - 1s 459us/step - loss: 1.5401 - categorical_accuracy: 0.3567 - val_loss: 1.5559 - val_categorical_accuracy: 0.3284
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.37745
# Epoch 36/1000
# 1584/1584 [==============================] - 1s 446us/step - loss: 1.5258 - categorical_accuracy: 0.3718 - val_loss: 1.5389 - val_categorical_accuracy: 0.3480
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.37745
# Epoch 37/1000
# 1584/1584 [==============================] - 1s 428us/step - loss: 1.5287 - categorical_accuracy: 0.3699 - val_loss: 1.5481 - val_categorical_accuracy: 0.3529
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.37745
# Epoch 38/1000
# 1584/1584 [==============================] - 1s 420us/step - loss: 1.5382 - categorical_accuracy: 0.3567 - val_loss: 1.5687 - val_categorical_accuracy: 0.3333
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.37745
# Epoch 39/1000
# 1584/1584 [==============================] - 1s 376us/step - loss: 1.5394 - categorical_accuracy: 0.3516 - val_loss: 1.5921 - val_categorical_accuracy: 0.3186
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.37745
# Epoch 40/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 1.5211 - categorical_accuracy: 0.3712 - val_loss: 1.6310 - val_categorical_accuracy: 0.2794
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.37745
# Epoch 41/1000
# 1584/1584 [==============================] - 1s 393us/step - loss: 1.5110 - categorical_accuracy: 0.3718 - val_loss: 1.5461 - val_categorical_accuracy: 0.3627
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.37745
# Epoch 42/1000
# 1584/1584 [==============================] - 1s 397us/step - loss: 1.5119 - categorical_accuracy: 0.3819 - val_loss: 1.5798 - val_categorical_accuracy: 0.3088
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.37745
# Epoch 43/1000
# 1584/1584 [==============================] - 1s 377us/step - loss: 1.4943 - categorical_accuracy: 0.3864 - val_loss: 1.5431 - val_categorical_accuracy: 0.3529
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.37745
# Epoch 44/1000
# 1584/1584 [==============================] - 1s 403us/step - loss: 1.5112 - categorical_accuracy: 0.3902 - val_loss: 1.5111 - val_categorical_accuracy: 0.3529
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.37745
# Epoch 45/1000
# 1584/1584 [==============================] - 1s 384us/step - loss: 1.4949 - categorical_accuracy: 0.4009 - val_loss: 1.5879 - val_categorical_accuracy: 0.3284
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.37745
# Epoch 46/1000
# 1584/1584 [==============================] - 1s 377us/step - loss: 1.4807 - categorical_accuracy: 0.3946 - val_loss: 1.4982 - val_categorical_accuracy: 0.3873
#
# Epoch 00046: val_categorical_accuracy improved from 0.37745 to 0.38725, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 47/1000
# 1584/1584 [==============================] - 1s 437us/step - loss: 1.4646 - categorical_accuracy: 0.3952 - val_loss: 1.5784 - val_categorical_accuracy: 0.3382
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.38725
# Epoch 48/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 1.4766 - categorical_accuracy: 0.3946 - val_loss: 1.5127 - val_categorical_accuracy: 0.3578
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.38725
# Epoch 49/1000
# 1584/1584 [==============================] - 1s 383us/step - loss: 1.4622 - categorical_accuracy: 0.3933 - val_loss: 1.5451 - val_categorical_accuracy: 0.3529
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.38725
# Epoch 50/1000
# 1584/1584 [==============================] - 1s 410us/step - loss: 1.4458 - categorical_accuracy: 0.4085 - val_loss: 1.4765 - val_categorical_accuracy: 0.3627
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.38725
# Epoch 51/1000
# 1584/1584 [==============================] - 1s 406us/step - loss: 1.4632 - categorical_accuracy: 0.3990 - val_loss: 1.5235 - val_categorical_accuracy: 0.3088
#
# Epoch 00051: val_categorical_accuracy did not improve from 0.38725
# Epoch 52/1000
# 1584/1584 [==============================] - 1s 379us/step - loss: 1.4419 - categorical_accuracy: 0.4047 - val_loss: 1.4956 - val_categorical_accuracy: 0.3971
#
# Epoch 00052: val_categorical_accuracy improved from 0.38725 to 0.39706, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 53/1000
# 1584/1584 [==============================] - 1s 407us/step - loss: 1.4330 - categorical_accuracy: 0.4053 - val_loss: 1.4999 - val_categorical_accuracy: 0.3676
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.39706
# Epoch 54/1000
# 1584/1584 [==============================] - 1s 380us/step - loss: 1.4188 - categorical_accuracy: 0.4255 - val_loss: 1.5957 - val_categorical_accuracy: 0.3382
#
# Epoch 00054: val_categorical_accuracy did not improve from 0.39706
# Epoch 55/1000
# 1584/1584 [==============================] - 1s 402us/step - loss: 1.4191 - categorical_accuracy: 0.4072 - val_loss: 1.4848 - val_categorical_accuracy: 0.3775
#
# Epoch 00055: val_categorical_accuracy did not improve from 0.39706
# Epoch 56/1000
# 1584/1584 [==============================] - 1s 401us/step - loss: 1.4113 - categorical_accuracy: 0.4198 - val_loss: 1.4813 - val_categorical_accuracy: 0.3922
#
# Epoch 00056: val_categorical_accuracy did not improve from 0.39706
# Epoch 57/1000
# 1584/1584 [==============================] - 1s 355us/step - loss: 1.4264 - categorical_accuracy: 0.4116 - val_loss: 1.4763 - val_categorical_accuracy: 0.4216
#
# Epoch 00057: val_categorical_accuracy improved from 0.39706 to 0.42157, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 58/1000
# 1584/1584 [==============================] - 1s 384us/step - loss: 1.4092 - categorical_accuracy: 0.4312 - val_loss: 1.4685 - val_categorical_accuracy: 0.3578
#
# Epoch 00058: val_categorical_accuracy did not improve from 0.42157
# Epoch 59/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 1.4243 - categorical_accuracy: 0.4249 - val_loss: 1.6160 - val_categorical_accuracy: 0.3578
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.42157
# Epoch 60/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 1.4181 - categorical_accuracy: 0.4274 - val_loss: 1.4700 - val_categorical_accuracy: 0.4020
#
# Epoch 00060: val_categorical_accuracy did not improve from 0.42157
# Epoch 61/1000
# 1584/1584 [==============================] - 1s 411us/step - loss: 1.3731 - categorical_accuracy: 0.4413 - val_loss: 1.4226 - val_categorical_accuracy: 0.3873
#
# Epoch 00061: val_categorical_accuracy did not improve from 0.42157
# Epoch 62/1000
# 1584/1584 [==============================] - 1s 392us/step - loss: 1.3849 - categorical_accuracy: 0.4343 - val_loss: 1.4785 - val_categorical_accuracy: 0.3529
#
# Epoch 00062: val_categorical_accuracy did not improve from 0.42157
# Epoch 63/1000
# 1584/1584 [==============================] - 1s 385us/step - loss: 1.3842 - categorical_accuracy: 0.4419 - val_loss: 1.4161 - val_categorical_accuracy: 0.4216
#
# Epoch 00063: val_categorical_accuracy did not improve from 0.42157
# Epoch 64/1000
# 1584/1584 [==============================] - 1s 383us/step - loss: 1.3788 - categorical_accuracy: 0.4381 - val_loss: 1.4270 - val_categorical_accuracy: 0.4020
#
# Epoch 00064: val_categorical_accuracy did not improve from 0.42157
# Epoch 65/1000
# 1584/1584 [==============================] - 1s 406us/step - loss: 1.3766 - categorical_accuracy: 0.4419 - val_loss: 1.5815 - val_categorical_accuracy: 0.3529
#
# Epoch 00065: val_categorical_accuracy did not improve from 0.42157
# Epoch 66/1000
# 1584/1584 [==============================] - 1s 412us/step - loss: 1.3683 - categorical_accuracy: 0.4571 - val_loss: 1.4753 - val_categorical_accuracy: 0.3824
#
# Epoch 00066: val_categorical_accuracy did not improve from 0.42157
# Epoch 67/1000
# 1584/1584 [==============================] - 1s 395us/step - loss: 1.3788 - categorical_accuracy: 0.4489 - val_loss: 1.4128 - val_categorical_accuracy: 0.4314
#
# Epoch 00067: val_categorical_accuracy improved from 0.42157 to 0.43137, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 68/1000
# 1584/1584 [==============================] - 1s 417us/step - loss: 1.3689 - categorical_accuracy: 0.4400 - val_loss: 1.4416 - val_categorical_accuracy: 0.4020
#
# Epoch 00068: val_categorical_accuracy did not improve from 0.43137
# Epoch 69/1000
# 1584/1584 [==============================] - 1s 384us/step - loss: 1.3395 - categorical_accuracy: 0.4640 - val_loss: 1.5786 - val_categorical_accuracy: 0.3578
#
# Epoch 00069: val_categorical_accuracy did not improve from 0.43137
# Epoch 70/1000
# 1584/1584 [==============================] - 1s 365us/step - loss: 1.3460 - categorical_accuracy: 0.4552 - val_loss: 1.3989 - val_categorical_accuracy: 0.4167
#
# Epoch 00070: val_categorical_accuracy did not improve from 0.43137
# Epoch 71/1000
# 1584/1584 [==============================] - 1s 414us/step - loss: 1.3538 - categorical_accuracy: 0.4476 - val_loss: 1.4525 - val_categorical_accuracy: 0.4069
#
# Epoch 00071: val_categorical_accuracy did not improve from 0.43137
# Epoch 72/1000
# 1584/1584 [==============================] - 1s 411us/step - loss: 1.3304 - categorical_accuracy: 0.4596 - val_loss: 1.3511 - val_categorical_accuracy: 0.4510
#
# Epoch 00072: val_categorical_accuracy improved from 0.43137 to 0.45098, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 73/1000
# 1584/1584 [==============================] - 1s 384us/step - loss: 1.3323 - categorical_accuracy: 0.4773 - val_loss: 1.4035 - val_categorical_accuracy: 0.4118
#
# Epoch 00073: val_categorical_accuracy did not improve from 0.45098
# Epoch 74/1000
# 1584/1584 [==============================] - 1s 390us/step - loss: 1.3484 - categorical_accuracy: 0.4571 - val_loss: 1.3717 - val_categorical_accuracy: 0.4118
#
# Epoch 00074: val_categorical_accuracy did not improve from 0.45098
# Epoch 75/1000
# 1584/1584 [==============================] - 1s 421us/step - loss: 1.3229 - categorical_accuracy: 0.4779 - val_loss: 1.3426 - val_categorical_accuracy: 0.4167
#
# Epoch 00075: val_categorical_accuracy did not improve from 0.45098
# Epoch 76/1000
# 1584/1584 [==============================] - 1s 395us/step - loss: 1.3262 - categorical_accuracy: 0.4558 - val_loss: 1.5655 - val_categorical_accuracy: 0.3333
#
# Epoch 00076: val_categorical_accuracy did not improve from 0.45098
# Epoch 77/1000
# 1584/1584 [==============================] - 1s 394us/step - loss: 1.3196 - categorical_accuracy: 0.4672 - val_loss: 1.3263 - val_categorical_accuracy: 0.4657
#
# Epoch 00077: val_categorical_accuracy improved from 0.45098 to 0.46569, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 78/1000
# 1584/1584 [==============================] - 1s 426us/step - loss: 1.3028 - categorical_accuracy: 0.4785 - val_loss: 1.5951 - val_categorical_accuracy: 0.3284
#
# Epoch 00078: val_categorical_accuracy did not improve from 0.46569
# Epoch 79/1000
# 1584/1584 [==============================] - 1s 414us/step - loss: 1.2784 - categorical_accuracy: 0.4912 - val_loss: 1.5494 - val_categorical_accuracy: 0.4510
#
# Epoch 00079: val_categorical_accuracy did not improve from 0.46569
# Epoch 80/1000
# 1584/1584 [==============================] - 1s 416us/step - loss: 1.3165 - categorical_accuracy: 0.4590 - val_loss: 1.4756 - val_categorical_accuracy: 0.3873
#
# Epoch 00080: val_categorical_accuracy did not improve from 0.46569
# Epoch 81/1000
# 1584/1584 [==============================] - 1s 398us/step - loss: 1.3351 - categorical_accuracy: 0.4722 - val_loss: 1.3895 - val_categorical_accuracy: 0.4216
#
# Epoch 00081: val_categorical_accuracy did not improve from 0.46569
# Epoch 82/1000
# 1584/1584 [==============================] - 1s 415us/step - loss: 1.2926 - categorical_accuracy: 0.4804 - val_loss: 1.5456 - val_categorical_accuracy: 0.3824
#
# Epoch 00082: val_categorical_accuracy did not improve from 0.46569
# Epoch 83/1000
# 1584/1584 [==============================] - 1s 386us/step - loss: 1.2898 - categorical_accuracy: 0.4893 - val_loss: 1.4578 - val_categorical_accuracy: 0.4020
#
# Epoch 00083: val_categorical_accuracy did not improve from 0.46569
# Epoch 84/1000
# 1584/1584 [==============================] - 1s 394us/step - loss: 1.2915 - categorical_accuracy: 0.4842 - val_loss: 1.4093 - val_categorical_accuracy: 0.4559
#
# Epoch 00084: val_categorical_accuracy did not improve from 0.46569
# Epoch 85/1000
# 1584/1584 [==============================] - 1s 433us/step - loss: 1.2944 - categorical_accuracy: 0.4735 - val_loss: 1.4241 - val_categorical_accuracy: 0.4167
#
# Epoch 00085: val_categorical_accuracy did not improve from 0.46569
# Epoch 86/1000
# 1584/1584 [==============================] - 1s 378us/step - loss: 1.2611 - categorical_accuracy: 0.5038 - val_loss: 1.9880 - val_categorical_accuracy: 0.3088
#
# Epoch 00086: val_categorical_accuracy did not improve from 0.46569
# Epoch 87/1000
# 1584/1584 [==============================] - 1s 381us/step - loss: 1.2678 - categorical_accuracy: 0.5000 - val_loss: 1.6078 - val_categorical_accuracy: 0.3431
#
# Epoch 00087: val_categorical_accuracy did not improve from 0.46569
# Epoch 88/1000
# 1584/1584 [==============================] - 1s 430us/step - loss: 1.2784 - categorical_accuracy: 0.4968 - val_loss: 1.3939 - val_categorical_accuracy: 0.4069
#
# Epoch 00088: val_categorical_accuracy did not improve from 0.46569
# Epoch 89/1000
# 1584/1584 [==============================] - 1s 448us/step - loss: 1.2720 - categorical_accuracy: 0.4937 - val_loss: 1.8200 - val_categorical_accuracy: 0.3284
#
# Epoch 00089: val_categorical_accuracy did not improve from 0.46569
# Epoch 90/1000
# 1584/1584 [==============================] - 1s 454us/step - loss: 1.2196 - categorical_accuracy: 0.5044 - val_loss: 1.5516 - val_categorical_accuracy: 0.3873
#
# Epoch 00090: val_categorical_accuracy did not improve from 0.46569
# Epoch 91/1000
# 1584/1584 [==============================] - 1s 490us/step - loss: 1.2467 - categorical_accuracy: 0.4912 - val_loss: 1.3678 - val_categorical_accuracy: 0.4608
#
# Epoch 00091: val_categorical_accuracy did not improve from 0.46569
# Epoch 92/1000
# 1584/1584 [==============================] - 1s 428us/step - loss: 1.2520 - categorical_accuracy: 0.4987 - val_loss: 1.3363 - val_categorical_accuracy: 0.4559
#
# Epoch 00092: val_categorical_accuracy did not improve from 0.46569
# Epoch 93/1000
# 1584/1584 [==============================] - 1s 396us/step - loss: 1.2483 - categorical_accuracy: 0.5019 - val_loss: 1.3058 - val_categorical_accuracy: 0.4412
#
# Epoch 00093: val_categorical_accuracy did not improve from 0.46569
# Epoch 94/1000
# 1584/1584 [==============================] - 1s 383us/step - loss: 1.2524 - categorical_accuracy: 0.5032 - val_loss: 1.3157 - val_categorical_accuracy: 0.4461
#
# Epoch 00094: val_categorical_accuracy did not improve from 0.46569
# Epoch 95/1000
# 1584/1584 [==============================] - 1s 387us/step - loss: 1.2408 - categorical_accuracy: 0.5069 - val_loss: 1.3141 - val_categorical_accuracy: 0.4510
#
# Epoch 00095: val_categorical_accuracy did not improve from 0.46569
# Epoch 96/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 1.2697 - categorical_accuracy: 0.4931 - val_loss: 1.4196 - val_categorical_accuracy: 0.4069
#
# Epoch 00096: val_categorical_accuracy did not improve from 0.46569
# Epoch 97/1000
# 1584/1584 [==============================] - 1s 379us/step - loss: 1.2540 - categorical_accuracy: 0.5032 - val_loss: 1.3939 - val_categorical_accuracy: 0.4314
#
# Epoch 00097: val_categorical_accuracy did not improve from 0.46569
# Epoch 98/1000
# 1584/1584 [==============================] - 1s 365us/step - loss: 1.2443 - categorical_accuracy: 0.5158 - val_loss: 1.3346 - val_categorical_accuracy: 0.4559
#
# Epoch 00098: val_categorical_accuracy did not improve from 0.46569
# Epoch 99/1000
# 1584/1584 [==============================] - 1s 413us/step - loss: 1.2168 - categorical_accuracy: 0.5126 - val_loss: 1.3139 - val_categorical_accuracy: 0.4510
#
# Epoch 00099: val_categorical_accuracy did not improve from 0.46569
# Epoch 100/1000
# 1584/1584 [==============================] - 1s 387us/step - loss: 1.2221 - categorical_accuracy: 0.5145 - val_loss: 1.4174 - val_categorical_accuracy: 0.4216
#
# Epoch 00100: val_categorical_accuracy did not improve from 0.46569
# Epoch 101/1000
# 1584/1584 [==============================] - 1s 420us/step - loss: 1.1771 - categorical_accuracy: 0.5341 - val_loss: 1.4247 - val_categorical_accuracy: 0.4265
#
# Epoch 00101: val_categorical_accuracy did not improve from 0.46569
# Epoch 102/1000
# 1584/1584 [==============================] - 1s 379us/step - loss: 1.2157 - categorical_accuracy: 0.5309 - val_loss: 1.4350 - val_categorical_accuracy: 0.4069
#
# Epoch 00102: val_categorical_accuracy did not improve from 0.46569
# Epoch 103/1000
# 1584/1584 [==============================] - 1s 395us/step - loss: 1.2185 - categorical_accuracy: 0.5196 - val_loss: 1.3302 - val_categorical_accuracy: 0.4510
#
# Epoch 00103: val_categorical_accuracy did not improve from 0.46569
# Epoch 104/1000
# 1584/1584 [==============================] - 1s 400us/step - loss: 1.2281 - categorical_accuracy: 0.5133 - val_loss: 1.5344 - val_categorical_accuracy: 0.3922
#
# Epoch 00104: val_categorical_accuracy did not improve from 0.46569
# Epoch 105/1000
# 1584/1584 [==============================] - 1s 368us/step - loss: 1.2053 - categorical_accuracy: 0.5164 - val_loss: 1.4008 - val_categorical_accuracy: 0.3922
#
# Epoch 00105: val_categorical_accuracy did not improve from 0.46569
# Epoch 106/1000
# 1584/1584 [==============================] - 1s 391us/step - loss: 1.1619 - categorical_accuracy: 0.5391 - val_loss: 1.2994 - val_categorical_accuracy: 0.4510
#
# Epoch 00106: val_categorical_accuracy did not improve from 0.46569
# Epoch 107/1000
# 1584/1584 [==============================] - 1s 397us/step - loss: 1.1976 - categorical_accuracy: 0.5208 - val_loss: 1.3224 - val_categorical_accuracy: 0.4755
#
# Epoch 00107: val_categorical_accuracy improved from 0.46569 to 0.47549, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 108/1000
# 1584/1584 [==============================] - 1s 390us/step - loss: 1.1920 - categorical_accuracy: 0.5215 - val_loss: 1.4942 - val_categorical_accuracy: 0.4069
#
# Epoch 00108: val_categorical_accuracy did not improve from 0.47549
# Epoch 109/1000
# 1584/1584 [==============================] - 1s 405us/step - loss: 1.1994 - categorical_accuracy: 0.5234 - val_loss: 1.3943 - val_categorical_accuracy: 0.4608
#
# Epoch 00109: val_categorical_accuracy did not improve from 0.47549
# Epoch 110/1000
# 1584/1584 [==============================] - 1s 432us/step - loss: 1.1985 - categorical_accuracy: 0.5164 - val_loss: 1.3623 - val_categorical_accuracy: 0.4412
#
# Epoch 00110: val_categorical_accuracy did not improve from 0.47549
# Epoch 111/1000
# 1584/1584 [==============================] - 1s 365us/step - loss: 1.1971 - categorical_accuracy: 0.5234 - val_loss: 1.4973 - val_categorical_accuracy: 0.4069
#
# Epoch 00111: val_categorical_accuracy did not improve from 0.47549
# Epoch 112/1000
# 1584/1584 [==============================] - 1s 380us/step - loss: 1.1655 - categorical_accuracy: 0.5360 - val_loss: 1.2351 - val_categorical_accuracy: 0.4706
#
# Epoch 00112: val_categorical_accuracy did not improve from 0.47549
# Epoch 113/1000
# 1584/1584 [==============================] - 1s 382us/step - loss: 1.1612 - categorical_accuracy: 0.5391 - val_loss: 1.3263 - val_categorical_accuracy: 0.4461
#
# Epoch 00113: val_categorical_accuracy did not improve from 0.47549
# Epoch 114/1000
# 1584/1584 [==============================] - 1s 400us/step - loss: 1.1765 - categorical_accuracy: 0.5455 - val_loss: 1.5037 - val_categorical_accuracy: 0.4216
#
# Epoch 00114: val_categorical_accuracy did not improve from 0.47549
# Epoch 115/1000
# 1584/1584 [==============================] - 1s 377us/step - loss: 1.1827 - categorical_accuracy: 0.5461 - val_loss: 1.2356 - val_categorical_accuracy: 0.5000
#
# Epoch 00115: val_categorical_accuracy improved from 0.47549 to 0.50000, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 116/1000
# 1584/1584 [==============================] - 1s 417us/step - loss: 1.1736 - categorical_accuracy: 0.5417 - val_loss: 1.6284 - val_categorical_accuracy: 0.3922
#
# Epoch 00116: val_categorical_accuracy did not improve from 0.50000
# Epoch 117/1000
# 1584/1584 [==============================] - 1s 363us/step - loss: 1.2145 - categorical_accuracy: 0.5196 - val_loss: 2.3563 - val_categorical_accuracy: 0.3088
#
# Epoch 00117: val_categorical_accuracy did not improve from 0.50000
# Epoch 118/1000
# 1584/1584 [==============================] - 1s 388us/step - loss: 1.1800 - categorical_accuracy: 0.5442 - val_loss: 1.7255 - val_categorical_accuracy: 0.3824
#
# Epoch 00118: val_categorical_accuracy did not improve from 0.50000
# Epoch 119/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 1.1610 - categorical_accuracy: 0.5417 - val_loss: 1.2733 - val_categorical_accuracy: 0.4608
#
# Epoch 00119: val_categorical_accuracy did not improve from 0.50000
# Epoch 120/1000
# 1584/1584 [==============================] - 1s 366us/step - loss: 1.1922 - categorical_accuracy: 0.5423 - val_loss: 1.4552 - val_categorical_accuracy: 0.4020
#
# Epoch 00120: val_categorical_accuracy did not improve from 0.50000
# Epoch 121/1000
# 1584/1584 [==============================] - 1s 380us/step - loss: 1.1545 - categorical_accuracy: 0.5379 - val_loss: 1.2582 - val_categorical_accuracy: 0.4657
#
# Epoch 00121: val_categorical_accuracy did not improve from 0.50000
# Epoch 122/1000
# 1584/1584 [==============================] - 1s 387us/step - loss: 1.1486 - categorical_accuracy: 0.5461 - val_loss: 1.2665 - val_categorical_accuracy: 0.4755
#
# Epoch 00122: val_categorical_accuracy did not improve from 0.50000
# Epoch 123/1000
# 1584/1584 [==============================] - 1s 400us/step - loss: 1.1106 - categorical_accuracy: 0.5707 - val_loss: 1.2771 - val_categorical_accuracy: 0.4657
#
# Epoch 00123: val_categorical_accuracy did not improve from 0.50000
# Epoch 124/1000
# 1584/1584 [==============================] - 1s 388us/step - loss: 1.1189 - categorical_accuracy: 0.5549 - val_loss: 1.2870 - val_categorical_accuracy: 0.4755
#
# Epoch 00124: val_categorical_accuracy did not improve from 0.50000
# Epoch 125/1000
# 1584/1584 [==============================] - 1s 361us/step - loss: 1.1030 - categorical_accuracy: 0.5562 - val_loss: 1.3862 - val_categorical_accuracy: 0.4559
#
# Epoch 00125: val_categorical_accuracy did not improve from 0.50000
# Epoch 126/1000
# 1584/1584 [==============================] - 1s 401us/step - loss: 1.1089 - categorical_accuracy: 0.5713 - val_loss: 1.2748 - val_categorical_accuracy: 0.4853
#
# Epoch 00126: val_categorical_accuracy did not improve from 0.50000
# Epoch 127/1000
# 1584/1584 [==============================] - 1s 387us/step - loss: 1.1209 - categorical_accuracy: 0.5467 - val_loss: 1.3681 - val_categorical_accuracy: 0.4412
#
# Epoch 00127: val_categorical_accuracy did not improve from 0.50000
# Epoch 128/1000
# 1584/1584 [==============================] - 1s 387us/step - loss: 1.1243 - categorical_accuracy: 0.5530 - val_loss: 1.5016 - val_categorical_accuracy: 0.4167
#
# Epoch 00128: val_categorical_accuracy did not improve from 0.50000
# Epoch 129/1000
# 1584/1584 [==============================] - 1s 394us/step - loss: 1.0862 - categorical_accuracy: 0.5745 - val_loss: 1.3578 - val_categorical_accuracy: 0.4461
#
# Epoch 00129: val_categorical_accuracy did not improve from 0.50000
# Epoch 130/1000
# 1584/1584 [==============================] - 1s 391us/step - loss: 1.1366 - categorical_accuracy: 0.5581 - val_loss: 1.2538 - val_categorical_accuracy: 0.5098
#
# Epoch 00130: val_categorical_accuracy improved from 0.50000 to 0.50980, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 131/1000
# 1584/1584 [==============================] - 1s 373us/step - loss: 1.0995 - categorical_accuracy: 0.5669 - val_loss: 1.5122 - val_categorical_accuracy: 0.4314
#
# Epoch 00131: val_categorical_accuracy did not improve from 0.50980
# Epoch 132/1000
# 1584/1584 [==============================] - 1s 378us/step - loss: 1.0968 - categorical_accuracy: 0.5644 - val_loss: 1.3792 - val_categorical_accuracy: 0.4706
#
# Epoch 00132: val_categorical_accuracy did not improve from 0.50980
# Epoch 133/1000
# 1584/1584 [==============================] - 1s 390us/step - loss: 1.0886 - categorical_accuracy: 0.5770 - val_loss: 1.5223 - val_categorical_accuracy: 0.4069
#
# Epoch 00133: val_categorical_accuracy did not improve from 0.50980
# Epoch 134/1000
# 1584/1584 [==============================] - 1s 415us/step - loss: 1.0650 - categorical_accuracy: 0.5814 - val_loss: 1.2311 - val_categorical_accuracy: 0.4608
#
# Epoch 00134: val_categorical_accuracy did not improve from 0.50980
# Epoch 135/1000
# 1584/1584 [==============================] - 1s 385us/step - loss: 1.0590 - categorical_accuracy: 0.5846 - val_loss: 1.2987 - val_categorical_accuracy: 0.4706
#
# Epoch 00135: val_categorical_accuracy did not improve from 0.50980
# Epoch 136/1000
# 1584/1584 [==============================] - 1s 387us/step - loss: 1.0648 - categorical_accuracy: 0.5903 - val_loss: 1.4686 - val_categorical_accuracy: 0.4363
#
# Epoch 00136: val_categorical_accuracy did not improve from 0.50980
# Epoch 137/1000
# 1584/1584 [==============================] - 1s 425us/step - loss: 1.0913 - categorical_accuracy: 0.5783 - val_loss: 1.2349 - val_categorical_accuracy: 0.5000
#
# Epoch 00137: val_categorical_accuracy did not improve from 0.50980
# Epoch 138/1000
# 1584/1584 [==============================] - 1s 367us/step - loss: 1.0540 - categorical_accuracy: 0.5884 - val_loss: 1.3351 - val_categorical_accuracy: 0.4951
#
# Epoch 00138: val_categorical_accuracy did not improve from 0.50980
# Epoch 139/1000
# 1584/1584 [==============================] - 1s 385us/step - loss: 1.0770 - categorical_accuracy: 0.5739 - val_loss: 1.3230 - val_categorical_accuracy: 0.4853
#
# Epoch 00139: val_categorical_accuracy did not improve from 0.50980
# Epoch 140/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 1.1052 - categorical_accuracy: 0.5676 - val_loss: 1.3551 - val_categorical_accuracy: 0.4461
#
# Epoch 00140: val_categorical_accuracy did not improve from 0.50980
# Epoch 141/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 1.0743 - categorical_accuracy: 0.5821 - val_loss: 1.8280 - val_categorical_accuracy: 0.3873
#
# Epoch 00141: val_categorical_accuracy did not improve from 0.50980
# Epoch 142/1000
# 1584/1584 [==============================] - 1s 399us/step - loss: 1.0594 - categorical_accuracy: 0.5972 - val_loss: 1.7391 - val_categorical_accuracy: 0.3480
#
# Epoch 00142: val_categorical_accuracy did not improve from 0.50980
# Epoch 143/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 1.0606 - categorical_accuracy: 0.5732 - val_loss: 1.3986 - val_categorical_accuracy: 0.4755
#
# Epoch 00143: val_categorical_accuracy did not improve from 0.50980
# Epoch 144/1000
# 1584/1584 [==============================] - 1s 392us/step - loss: 1.0634 - categorical_accuracy: 0.5650 - val_loss: 1.5287 - val_categorical_accuracy: 0.3971
#
# Epoch 00144: val_categorical_accuracy did not improve from 0.50980
# Epoch 145/1000
# 1584/1584 [==============================] - 1s 363us/step - loss: 1.0571 - categorical_accuracy: 0.5859 - val_loss: 1.3476 - val_categorical_accuracy: 0.4853
#
# Epoch 00145: val_categorical_accuracy did not improve from 0.50980
# Epoch 146/1000
# 1584/1584 [==============================] - 1s 415us/step - loss: 1.0670 - categorical_accuracy: 0.5764 - val_loss: 1.1969 - val_categorical_accuracy: 0.5000
#
# Epoch 00146: val_categorical_accuracy did not improve from 0.50980
# Epoch 147/1000
# 1584/1584 [==============================] - 1s 481us/step - loss: 1.0382 - categorical_accuracy: 0.5997 - val_loss: 1.2665 - val_categorical_accuracy: 0.4706
#
# Epoch 00147: val_categorical_accuracy did not improve from 0.50980
# Epoch 148/1000
# 1584/1584 [==============================] - 1s 452us/step - loss: 1.0226 - categorical_accuracy: 0.6080 - val_loss: 1.1930 - val_categorical_accuracy: 0.5098
#
# Epoch 00148: val_categorical_accuracy improved from 0.50980 to 0.50980, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 149/1000
# 1584/1584 [==============================] - 1s 409us/step - loss: 1.0250 - categorical_accuracy: 0.6016 - val_loss: 1.4893 - val_categorical_accuracy: 0.3529
#
# Epoch 00149: val_categorical_accuracy did not improve from 0.50980
# Epoch 150/1000
# 1584/1584 [==============================] - 1s 394us/step - loss: 1.0916 - categorical_accuracy: 0.5688 - val_loss: 1.3087 - val_categorical_accuracy: 0.5147
#
# Epoch 00150: val_categorical_accuracy improved from 0.50980 to 0.51471, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 151/1000
# 1584/1584 [==============================] - 1s 424us/step - loss: 1.0552 - categorical_accuracy: 0.5859 - val_loss: 1.2224 - val_categorical_accuracy: 0.5049
#
# Epoch 00151: val_categorical_accuracy did not improve from 0.51471
# Epoch 152/1000
# 1584/1584 [==============================] - 1s 394us/step - loss: 1.0252 - categorical_accuracy: 0.5953 - val_loss: 1.2567 - val_categorical_accuracy: 0.5049
#
# Epoch 00152: val_categorical_accuracy did not improve from 0.51471
# Epoch 153/1000
# 1584/1584 [==============================] - 1s 390us/step - loss: 1.0169 - categorical_accuracy: 0.5991 - val_loss: 1.3934 - val_categorical_accuracy: 0.4706
#
# Epoch 00153: val_categorical_accuracy did not improve from 0.51471
# Epoch 154/1000
# 1584/1584 [==============================] - 1s 420us/step - loss: 1.0394 - categorical_accuracy: 0.5934 - val_loss: 1.5278 - val_categorical_accuracy: 0.3922
#
# Epoch 00154: val_categorical_accuracy did not improve from 0.51471
# Epoch 155/1000
# 1584/1584 [==============================] - 1s 400us/step - loss: 1.0301 - categorical_accuracy: 0.6035 - val_loss: 2.0596 - val_categorical_accuracy: 0.3431
#
# Epoch 00155: val_categorical_accuracy did not improve from 0.51471
# Epoch 156/1000
# 1584/1584 [==============================] - 1s 380us/step - loss: 1.0112 - categorical_accuracy: 0.6061 - val_loss: 1.4397 - val_categorical_accuracy: 0.3971
#
# Epoch 00156: val_categorical_accuracy did not improve from 0.51471
# Epoch 157/1000
# 1584/1584 [==============================] - 1s 385us/step - loss: 1.0133 - categorical_accuracy: 0.6023 - val_loss: 1.3556 - val_categorical_accuracy: 0.4755
#
# Epoch 00157: val_categorical_accuracy did not improve from 0.51471
# Epoch 158/1000
# 1584/1584 [==============================] - 1s 377us/step - loss: 1.0207 - categorical_accuracy: 0.5947 - val_loss: 1.1870 - val_categorical_accuracy: 0.5000
#
# Epoch 00158: val_categorical_accuracy did not improve from 0.51471
# Epoch 159/1000
# 1584/1584 [==============================] - 1s 391us/step - loss: 1.0457 - categorical_accuracy: 0.5840 - val_loss: 1.2576 - val_categorical_accuracy: 0.4804
#
# Epoch 00159: val_categorical_accuracy did not improve from 0.51471
# Epoch 160/1000
# 1584/1584 [==============================] - 1s 386us/step - loss: 1.0168 - categorical_accuracy: 0.6004 - val_loss: 1.2136 - val_categorical_accuracy: 0.5441
#
# Epoch 00160: val_categorical_accuracy improved from 0.51471 to 0.54412, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 161/1000
# 1584/1584 [==============================] - 1s 414us/step - loss: 1.0141 - categorical_accuracy: 0.6105 - val_loss: 1.4779 - val_categorical_accuracy: 0.4510
#
# Epoch 00161: val_categorical_accuracy did not improve from 0.54412
# Epoch 162/1000
# 1584/1584 [==============================] - 1s 384us/step - loss: 1.0149 - categorical_accuracy: 0.5960 - val_loss: 1.3000 - val_categorical_accuracy: 0.4951
#
# Epoch 00162: val_categorical_accuracy did not improve from 0.54412
# Epoch 163/1000
# 1584/1584 [==============================] - 1s 408us/step - loss: 1.0103 - categorical_accuracy: 0.6130 - val_loss: 1.7570 - val_categorical_accuracy: 0.3480
#
# Epoch 00163: val_categorical_accuracy did not improve from 0.54412
# Epoch 164/1000
# 1584/1584 [==============================] - 1s 369us/step - loss: 0.9948 - categorical_accuracy: 0.6231 - val_loss: 1.2483 - val_categorical_accuracy: 0.4510
#
# Epoch 00164: val_categorical_accuracy did not improve from 0.54412
# Epoch 165/1000
# 1584/1584 [==============================] - 1s 379us/step - loss: 0.9882 - categorical_accuracy: 0.6332 - val_loss: 1.1750 - val_categorical_accuracy: 0.5343
#
# Epoch 00165: val_categorical_accuracy did not improve from 0.54412
# Epoch 166/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 0.9620 - categorical_accuracy: 0.6155 - val_loss: 1.2346 - val_categorical_accuracy: 0.4755
#
# Epoch 00166: val_categorical_accuracy did not improve from 0.54412
# Epoch 167/1000
# 1584/1584 [==============================] - 1s 415us/step - loss: 0.9782 - categorical_accuracy: 0.6206 - val_loss: 1.1868 - val_categorical_accuracy: 0.5490
#
# Epoch 00167: val_categorical_accuracy improved from 0.54412 to 0.54902, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 168/1000
# 1584/1584 [==============================] - 1s 393us/step - loss: 0.9631 - categorical_accuracy: 0.6332 - val_loss: 1.1483 - val_categorical_accuracy: 0.4902
#
# Epoch 00168: val_categorical_accuracy did not improve from 0.54902
# Epoch 169/1000
# 1584/1584 [==============================] - 1s 405us/step - loss: 0.9865 - categorical_accuracy: 0.6067 - val_loss: 1.2323 - val_categorical_accuracy: 0.5049
#
# Epoch 00169: val_categorical_accuracy did not improve from 0.54902
# Epoch 170/1000
# 1584/1584 [==============================] - 1s 385us/step - loss: 1.0024 - categorical_accuracy: 0.5979 - val_loss: 1.4153 - val_categorical_accuracy: 0.4412
#
# Epoch 00170: val_categorical_accuracy did not improve from 0.54902
# Epoch 171/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 1.0164 - categorical_accuracy: 0.5960 - val_loss: 1.2313 - val_categorical_accuracy: 0.5098
#
# Epoch 00171: val_categorical_accuracy did not improve from 0.54902
# Epoch 172/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 1.0074 - categorical_accuracy: 0.6042 - val_loss: 1.2130 - val_categorical_accuracy: 0.5343
#
# Epoch 00172: val_categorical_accuracy did not improve from 0.54902
# Epoch 173/1000
# 1584/1584 [==============================] - 1s 363us/step - loss: 1.0157 - categorical_accuracy: 0.6061 - val_loss: 1.2105 - val_categorical_accuracy: 0.5588
#
# Epoch 00173: val_categorical_accuracy improved from 0.54902 to 0.55882, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 174/1000
# 1584/1584 [==============================] - 1s 382us/step - loss: 0.9536 - categorical_accuracy: 0.6237 - val_loss: 1.2087 - val_categorical_accuracy: 0.5000
#
# Epoch 00174: val_categorical_accuracy did not improve from 0.55882
# Epoch 175/1000
# 1584/1584 [==============================] - 1s 368us/step - loss: 0.9828 - categorical_accuracy: 0.6256 - val_loss: 1.1745 - val_categorical_accuracy: 0.5294
#
# Epoch 00175: val_categorical_accuracy did not improve from 0.55882
# Epoch 176/1000
# 1584/1584 [==============================] - 1s 388us/step - loss: 0.9697 - categorical_accuracy: 0.6231 - val_loss: 1.4882 - val_categorical_accuracy: 0.4412
#
# Epoch 00176: val_categorical_accuracy did not improve from 0.55882
# Epoch 177/1000
# 1584/1584 [==============================] - 1s 405us/step - loss: 0.9611 - categorical_accuracy: 0.6319 - val_loss: 1.1845 - val_categorical_accuracy: 0.5049
#
# Epoch 00177: val_categorical_accuracy did not improve from 0.55882
# Epoch 178/1000
# 1584/1584 [==============================] - 1s 401us/step - loss: 0.9300 - categorical_accuracy: 0.6439 - val_loss: 1.1809 - val_categorical_accuracy: 0.5392
#
# Epoch 00178: val_categorical_accuracy did not improve from 0.55882
# Epoch 179/1000
# 1584/1584 [==============================] - 1s 378us/step - loss: 0.9471 - categorical_accuracy: 0.6288 - val_loss: 1.2094 - val_categorical_accuracy: 0.5049
#
# Epoch 00179: val_categorical_accuracy did not improve from 0.55882
# Epoch 180/1000
# 1584/1584 [==============================] - 1s 386us/step - loss: 0.9009 - categorical_accuracy: 0.6503 - val_loss: 1.0393 - val_categorical_accuracy: 0.5637
#
# Epoch 00180: val_categorical_accuracy improved from 0.55882 to 0.56373, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 181/1000
# 1584/1584 [==============================] - 1s 423us/step - loss: 0.9290 - categorical_accuracy: 0.6332 - val_loss: 1.6800 - val_categorical_accuracy: 0.4412
#
# Epoch 00181: val_categorical_accuracy did not improve from 0.56373
# Epoch 182/1000
# 1584/1584 [==============================] - 1s 379us/step - loss: 0.9821 - categorical_accuracy: 0.6149 - val_loss: 1.5404 - val_categorical_accuracy: 0.4314
#
# Epoch 00182: val_categorical_accuracy did not improve from 0.56373
# Epoch 183/1000
# 1584/1584 [==============================] - 1s 405us/step - loss: 0.9408 - categorical_accuracy: 0.6326 - val_loss: 1.1463 - val_categorical_accuracy: 0.5588
#
# Epoch 00183: val_categorical_accuracy did not improve from 0.56373
# Epoch 184/1000
# 1584/1584 [==============================] - 1s 382us/step - loss: 0.9419 - categorical_accuracy: 0.6162 - val_loss: 1.4759 - val_categorical_accuracy: 0.5196
#
# Epoch 00184: val_categorical_accuracy did not improve from 0.56373
# Epoch 185/1000
# 1584/1584 [==============================] - 1s 385us/step - loss: 0.9209 - categorical_accuracy: 0.6364 - val_loss: 1.0929 - val_categorical_accuracy: 0.5784
#
# Epoch 00185: val_categorical_accuracy improved from 0.56373 to 0.57843, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 186/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 0.9254 - categorical_accuracy: 0.6427 - val_loss: 1.4552 - val_categorical_accuracy: 0.4510
#
# Epoch 00186: val_categorical_accuracy did not improve from 0.57843
# Epoch 187/1000
# 1584/1584 [==============================] - 1s 380us/step - loss: 0.9007 - categorical_accuracy: 0.6521 - val_loss: 1.0927 - val_categorical_accuracy: 0.5588
#
# Epoch 00187: val_categorical_accuracy did not improve from 0.57843
# Epoch 188/1000
# 1584/1584 [==============================] - 1s 382us/step - loss: 0.9078 - categorical_accuracy: 0.6395 - val_loss: 2.3413 - val_categorical_accuracy: 0.3824
#
# Epoch 00188: val_categorical_accuracy did not improve from 0.57843
# Epoch 189/1000
# 1584/1584 [==============================] - 1s 395us/step - loss: 0.9167 - categorical_accuracy: 0.6332 - val_loss: 2.2851 - val_categorical_accuracy: 0.3235
#
# Epoch 00189: val_categorical_accuracy did not improve from 0.57843
# Epoch 190/1000
# 1584/1584 [==============================] - 1s 417us/step - loss: 0.9237 - categorical_accuracy: 0.6521 - val_loss: 1.3581 - val_categorical_accuracy: 0.4461
#
# Epoch 00190: val_categorical_accuracy did not improve from 0.57843
# Epoch 191/1000
# 1584/1584 [==============================] - 1s 388us/step - loss: 0.9368 - categorical_accuracy: 0.6370 - val_loss: 1.5944 - val_categorical_accuracy: 0.4069
#
# Epoch 00191: val_categorical_accuracy did not improve from 0.57843
# Epoch 192/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 0.9822 - categorical_accuracy: 0.6162 - val_loss: 1.2498 - val_categorical_accuracy: 0.5049
#
# Epoch 00192: val_categorical_accuracy did not improve from 0.57843
# Epoch 193/1000
# ...
#
# Epoch 00935: val_categorical_accuracy did not improve from 0.76471
# Epoch 936/1000
# 1584/1584 [==============================] - 1s 390us/step - loss: 0.2677 - categorical_accuracy: 0.9085 - val_loss: 1.1741 - val_categorical_accuracy: 0.7500
#
# Epoch 00936: val_categorical_accuracy did not improve from 0.76471
# Epoch 937/1000
# 1584/1584 [==============================] - 1s 403us/step - loss: 0.2772 - categorical_accuracy: 0.9028 - val_loss: 1.3274 - val_categorical_accuracy: 0.6324
#
# Epoch 00937: val_categorical_accuracy did not improve from 0.76471
# Epoch 938/1000
# 1584/1584 [==============================] - 1s 392us/step - loss: 0.2722 - categorical_accuracy: 0.9028 - val_loss: 1.0243 - val_categorical_accuracy: 0.7206
#
# Epoch 00938: val_categorical_accuracy did not improve from 0.76471
# Epoch 939/1000
# 1584/1584 [==============================] - 1s 388us/step - loss: 0.2800 - categorical_accuracy: 0.9059 - val_loss: 1.1191 - val_categorical_accuracy: 0.7353
#
# Epoch 00939: val_categorical_accuracy did not improve from 0.76471
# Epoch 940/1000
# 1584/1584 [==============================] - 1s 413us/step - loss: 0.2813 - categorical_accuracy: 0.8990 - val_loss: 1.0009 - val_categorical_accuracy: 0.7108
#
# Epoch 00940: val_categorical_accuracy did not improve from 0.76471
# Epoch 941/1000
# 1584/1584 [==============================] - 1s 394us/step - loss: 0.2946 - categorical_accuracy: 0.9003 - val_loss: 0.9417 - val_categorical_accuracy: 0.7451
#
# Epoch 00941: val_categorical_accuracy did not improve from 0.76471
# Epoch 942/1000
# 1584/1584 [==============================] - 1s 383us/step - loss: 0.2565 - categorical_accuracy: 0.9154 - val_loss: 1.0470 - val_categorical_accuracy: 0.6863
#
# Epoch 00942: val_categorical_accuracy did not improve from 0.76471
# Epoch 943/1000
# 1584/1584 [==============================] - 1s 404us/step - loss: 0.2703 - categorical_accuracy: 0.9104 - val_loss: 1.0076 - val_categorical_accuracy: 0.7451
#
# Epoch 00943: val_categorical_accuracy did not improve from 0.76471
# Epoch 944/1000
# 1584/1584 [==============================] - 1s 377us/step - loss: 0.2432 - categorical_accuracy: 0.9135 - val_loss: 0.9706 - val_categorical_accuracy: 0.7255
#
# Epoch 00944: val_categorical_accuracy did not improve from 0.76471
# Epoch 945/1000
# 1584/1584 [==============================] - 1s 402us/step - loss: 0.2738 - categorical_accuracy: 0.9078 - val_loss: 1.0054 - val_categorical_accuracy: 0.7549
#
# Epoch 00945: val_categorical_accuracy did not improve from 0.76471
# Epoch 946/1000
# 1584/1584 [==============================] - 1s 384us/step - loss: 0.2440 - categorical_accuracy: 0.9192 - val_loss: 1.1255 - val_categorical_accuracy: 0.6863
#
# Epoch 00946: val_categorical_accuracy did not improve from 0.76471
# Epoch 947/1000
# 1584/1584 [==============================] - 1s 383us/step - loss: 0.2632 - categorical_accuracy: 0.9034 - val_loss: 1.1582 - val_categorical_accuracy: 0.7304
#
# Epoch 00947: val_categorical_accuracy did not improve from 0.76471
# Epoch 948/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 0.2529 - categorical_accuracy: 0.9110 - val_loss: 1.2126 - val_categorical_accuracy: 0.7108
#
# Epoch 00948: val_categorical_accuracy did not improve from 0.76471
# Epoch 949/1000
# 1584/1584 [==============================] - 1s 358us/step - loss: 0.2433 - categorical_accuracy: 0.9148 - val_loss: 0.9726 - val_categorical_accuracy: 0.7157
#
# Epoch 00949: val_categorical_accuracy did not improve from 0.76471
# Epoch 950/1000
# 1584/1584 [==============================] - 1s 393us/step - loss: 0.2584 - categorical_accuracy: 0.8996 - val_loss: 1.0843 - val_categorical_accuracy: 0.7059
#
# Epoch 00950: val_categorical_accuracy did not improve from 0.76471
# Epoch 951/1000
# 1584/1584 [==============================] - 1s 369us/step - loss: 0.2530 - categorical_accuracy: 0.9230 - val_loss: 1.2007 - val_categorical_accuracy: 0.6863
#
# Epoch 00951: val_categorical_accuracy did not improve from 0.76471
# Epoch 952/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 0.2704 - categorical_accuracy: 0.9034 - val_loss: 1.3453 - val_categorical_accuracy: 0.6225
#
# Epoch 00952: val_categorical_accuracy did not improve from 0.76471
# Epoch 953/1000
# 1584/1584 [==============================] - 1s 380us/step - loss: 0.2806 - categorical_accuracy: 0.8958 - val_loss: 1.2933 - val_categorical_accuracy: 0.6667
#
# Epoch 00953: val_categorical_accuracy did not improve from 0.76471
# Epoch 954/1000
# 1584/1584 [==============================] - 1s 364us/step - loss: 0.3097 - categorical_accuracy: 0.8965 - val_loss: 1.2582 - val_categorical_accuracy: 0.6569
#
# Epoch 00954: val_categorical_accuracy did not improve from 0.76471
# Epoch 955/1000
# 1584/1584 [==============================] - 1s 368us/step - loss: 0.2518 - categorical_accuracy: 0.9135 - val_loss: 0.9638 - val_categorical_accuracy: 0.7059
#
# Epoch 00955: val_categorical_accuracy did not improve from 0.76471
# Epoch 956/1000
# 1584/1584 [==============================] - 1s 352us/step - loss: 0.2733 - categorical_accuracy: 0.9072 - val_loss: 1.1412 - val_categorical_accuracy: 0.7157
#
# Epoch 00956: val_categorical_accuracy did not improve from 0.76471
# Epoch 957/1000
# 1584/1584 [==============================] - 1s 382us/step - loss: 0.2387 - categorical_accuracy: 0.9205 - val_loss: 1.1126 - val_categorical_accuracy: 0.6912
#
# Epoch 00957: val_categorical_accuracy did not improve from 0.76471
# Epoch 958/1000
# 1584/1584 [==============================] - 1s 363us/step - loss: 0.2529 - categorical_accuracy: 0.9078 - val_loss: 0.9791 - val_categorical_accuracy: 0.6961
#
# Epoch 00958: val_categorical_accuracy did not improve from 0.76471
# Epoch 959/1000
# 1584/1584 [==============================] - 1s 383us/step - loss: 0.2606 - categorical_accuracy: 0.9091 - val_loss: 0.9388 - val_categorical_accuracy: 0.7304
#
# Epoch 00959: val_categorical_accuracy did not improve from 0.76471
# Epoch 960/1000
# 1584/1584 [==============================] - 1s 400us/step - loss: 0.2612 - categorical_accuracy: 0.9078 - val_loss: 0.9537 - val_categorical_accuracy: 0.7206
#
# Epoch 00960: val_categorical_accuracy did not improve from 0.76471
# Epoch 961/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 0.2462 - categorical_accuracy: 0.9186 - val_loss: 1.2113 - val_categorical_accuracy: 0.6569
#
# Epoch 00961: val_categorical_accuracy did not improve from 0.76471
# Epoch 962/1000
# 1584/1584 [==============================] - 1s 384us/step - loss: 0.2343 - categorical_accuracy: 0.9135 - val_loss: 1.1103 - val_categorical_accuracy: 0.7304
#
# Epoch 00962: val_categorical_accuracy did not improve from 0.76471
# Epoch 963/1000
# 1584/1584 [==============================] - 1s 394us/step - loss: 0.2355 - categorical_accuracy: 0.9198 - val_loss: 1.1360 - val_categorical_accuracy: 0.7059
#
# Epoch 00963: val_categorical_accuracy did not improve from 0.76471
# Epoch 964/1000
# 1584/1584 [==============================] - 1s 375us/step - loss: 0.2146 - categorical_accuracy: 0.9261 - val_loss: 0.9594 - val_categorical_accuracy: 0.7010
#
# Epoch 00964: val_categorical_accuracy did not improve from 0.76471
# Epoch 965/1000
# 1584/1584 [==============================] - 1s 393us/step - loss: 0.2305 - categorical_accuracy: 0.9255 - val_loss: 0.9085 - val_categorical_accuracy: 0.7353
#
# Epoch 00965: val_categorical_accuracy did not improve from 0.76471
# Epoch 966/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 0.2455 - categorical_accuracy: 0.9192 - val_loss: 1.2400 - val_categorical_accuracy: 0.6912
#
# Epoch 00966: val_categorical_accuracy did not improve from 0.76471
# Epoch 967/1000
# 1584/1584 [==============================] - 1s 369us/step - loss: 0.2582 - categorical_accuracy: 0.9085 - val_loss: 1.2201 - val_categorical_accuracy: 0.6863
#
# Epoch 00967: val_categorical_accuracy did not improve from 0.76471
# Epoch 968/1000
# 1584/1584 [==============================] - 1s 379us/step - loss: 0.2726 - categorical_accuracy: 0.9034 - val_loss: 1.0586 - val_categorical_accuracy: 0.7500
#
# Epoch 00968: val_categorical_accuracy did not improve from 0.76471
# Epoch 969/1000
# 1584/1584 [==============================] - 1s 378us/step - loss: 0.2389 - categorical_accuracy: 0.9205 - val_loss: 1.0561 - val_categorical_accuracy: 0.6765
#
# Epoch 00969: val_categorical_accuracy did not improve from 0.76471
# Epoch 970/1000
# 1584/1584 [==============================] - 1s 378us/step - loss: 0.3208 - categorical_accuracy: 0.8914 - val_loss: 1.0428 - val_categorical_accuracy: 0.7206
#
# Epoch 00970: val_categorical_accuracy did not improve from 0.76471
# Epoch 971/1000
# 1584/1584 [==============================] - 1s 371us/step - loss: 0.2333 - categorical_accuracy: 0.9211 - val_loss: 0.9941 - val_categorical_accuracy: 0.7500
#
# Epoch 00971: val_categorical_accuracy did not improve from 0.76471
# Epoch 972/1000
# 1584/1584 [==============================] - 1s 364us/step - loss: 0.2764 - categorical_accuracy: 0.8990 - val_loss: 1.0182 - val_categorical_accuracy: 0.7402
#
# Epoch 00972: val_categorical_accuracy did not improve from 0.76471
# Epoch 973/1000
# 1584/1584 [==============================] - 1s 390us/step - loss: 0.2530 - categorical_accuracy: 0.9223 - val_loss: 1.0769 - val_categorical_accuracy: 0.7010
#
# Epoch 00973: val_categorical_accuracy did not improve from 0.76471
# Epoch 974/1000
# 1584/1584 [==============================] - 1s 374us/step - loss: 0.2505 - categorical_accuracy: 0.9198 - val_loss: 0.9697 - val_categorical_accuracy: 0.7353
#
# Epoch 00974: val_categorical_accuracy did not improve from 0.76471
# Epoch 975/1000
# 1584/1584 [==============================] - 1s 389us/step - loss: 0.2523 - categorical_accuracy: 0.9028 - val_loss: 1.1849 - val_categorical_accuracy: 0.6814
#
# Epoch 00975: val_categorical_accuracy did not improve from 0.76471
# Epoch 976/1000
# 1584/1584 [==============================] - 1s 370us/step - loss: 0.2080 - categorical_accuracy: 0.9261 - val_loss: 0.9638 - val_categorical_accuracy: 0.7451
#
# Epoch 00976: val_categorical_accuracy did not improve from 0.76471
# Epoch 977/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 0.2227 - categorical_accuracy: 0.9192 - val_loss: 1.0827 - val_categorical_accuracy: 0.6667
#
# Epoch 00977: val_categorical_accuracy did not improve from 0.76471
# Epoch 978/1000
# 1584/1584 [==============================] - 1s 377us/step - loss: 0.2285 - categorical_accuracy: 0.9198 - val_loss: 1.0296 - val_categorical_accuracy: 0.6863
#
# Epoch 00978: val_categorical_accuracy did not improve from 0.76471
# Epoch 979/1000
# 1584/1584 [==============================] - 1s 362us/step - loss: 0.2167 - categorical_accuracy: 0.9249 - val_loss: 1.0794 - val_categorical_accuracy: 0.7206
#
# Epoch 00979: val_categorical_accuracy did not improve from 0.76471
# Epoch 980/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 0.2218 - categorical_accuracy: 0.9205 - val_loss: 1.0268 - val_categorical_accuracy: 0.7304
#
# Epoch 00980: val_categorical_accuracy did not improve from 0.76471
# Epoch 981/1000
# 1584/1584 [==============================] - 1s 384us/step - loss: 0.2756 - categorical_accuracy: 0.9148 - val_loss: 0.9536 - val_categorical_accuracy: 0.7157
#
# Epoch 00981: val_categorical_accuracy did not improve from 0.76471
# Epoch 982/1000
# 1584/1584 [==============================] - 1s 372us/step - loss: 0.2626 - categorical_accuracy: 0.9116 - val_loss: 1.4964 - val_categorical_accuracy: 0.6225
#
# Epoch 00982: val_categorical_accuracy did not improve from 0.76471
# Epoch 983/1000
# 1584/1584 [==============================] - 1s 359us/step - loss: 0.2921 - categorical_accuracy: 0.9078 - val_loss: 1.1931 - val_categorical_accuracy: 0.6863
#
# Epoch 00983: val_categorical_accuracy did not improve from 0.76471
# Epoch 984/1000
# 1584/1584 [==============================] - 1s 380us/step - loss: 0.3141 - categorical_accuracy: 0.8977 - val_loss: 1.0161 - val_categorical_accuracy: 0.7157
#
# Epoch 00984: val_categorical_accuracy did not improve from 0.76471
# Epoch 985/1000
# 1584/1584 [==============================] - 1s 385us/step - loss: 0.2588 - categorical_accuracy: 0.9091 - val_loss: 0.9268 - val_categorical_accuracy: 0.7451
#
# Epoch 00985: val_categorical_accuracy did not improve from 0.76471
# Epoch 986/1000
# 1584/1584 [==============================] - 1s 351us/step - loss: 0.2664 - categorical_accuracy: 0.9148 - val_loss: 1.0646 - val_categorical_accuracy: 0.7255
#
# Epoch 00986: val_categorical_accuracy did not improve from 0.76471
# Epoch 987/1000
# 1584/1584 [==============================] - 1s 371us/step - loss: 0.2736 - categorical_accuracy: 0.9072 - val_loss: 1.6620 - val_categorical_accuracy: 0.6618
#
# Epoch 00987: val_categorical_accuracy did not improve from 0.76471
# Epoch 988/1000
# 1584/1584 [==============================] - 1s 381us/step - loss: 0.2691 - categorical_accuracy: 0.9173 - val_loss: 1.1490 - val_categorical_accuracy: 0.7059
#
# Epoch 00988: val_categorical_accuracy did not improve from 0.76471
# Epoch 989/1000
# 1584/1584 [==============================] - 1s 382us/step - loss: 0.2644 - categorical_accuracy: 0.9135 - val_loss: 1.1301 - val_categorical_accuracy: 0.6618
#
# Epoch 00989: val_categorical_accuracy did not improve from 0.76471
# Epoch 990/1000
# 1584/1584 [==============================] - 1s 379us/step - loss: 0.2625 - categorical_accuracy: 0.9015 - val_loss: 0.8739 - val_categorical_accuracy: 0.7745
#
# Epoch 00990: val_categorical_accuracy improved from 0.76471 to 0.77451, saving model to Checkpoints/weights_model_0_dr03_m5_new.hdf5
# Epoch 991/1000
# 1584/1584 [==============================] - 1s 370us/step - loss: 0.2471 - categorical_accuracy: 0.9154 - val_loss: 1.2890 - val_categorical_accuracy: 0.6716
#
# Epoch 00991: val_categorical_accuracy did not improve from 0.77451
# Epoch 992/1000
# 1584/1584 [==============================] - 1s 386us/step - loss: 0.2504 - categorical_accuracy: 0.9148 - val_loss: 1.3520 - val_categorical_accuracy: 0.6520
#
# Epoch 00992: val_categorical_accuracy did not improve from 0.77451
# Epoch 993/1000
# 1584/1584 [==============================] - 1s 387us/step - loss: 0.3295 - categorical_accuracy: 0.8857 - val_loss: 1.1422 - val_categorical_accuracy: 0.6618
#
# Epoch 00993: val_categorical_accuracy did not improve from 0.77451
# Epoch 994/1000
# 1584/1584 [==============================] - 1s 382us/step - loss: 0.3528 - categorical_accuracy: 0.8832 - val_loss: 1.2708 - val_categorical_accuracy: 0.6520
#
# Epoch 00994: val_categorical_accuracy did not improve from 0.77451
# Epoch 995/1000
# 1584/1584 [==============================] - 1s 385us/step - loss: 0.3067 - categorical_accuracy: 0.9015 - val_loss: 1.5099 - val_categorical_accuracy: 0.6078
#
# Epoch 00995: val_categorical_accuracy did not improve from 0.77451
# Epoch 996/1000
# 1584/1584 [==============================] - 1s 379us/step - loss: 0.3215 - categorical_accuracy: 0.8933 - val_loss: 1.2126 - val_categorical_accuracy: 0.7108
#
# Epoch 00996: val_categorical_accuracy did not improve from 0.77451
# Epoch 997/1000
# 1584/1584 [==============================] - 1s 366us/step - loss: 0.2785 - categorical_accuracy: 0.9091 - val_loss: 1.0872 - val_categorical_accuracy: 0.6863
#
# Epoch 00997: val_categorical_accuracy did not improve from 0.77451
# Epoch 998/1000
# 1584/1584 [==============================] - 1s 379us/step - loss: 0.2521 - categorical_accuracy: 0.9085 - val_loss: 1.1208 - val_categorical_accuracy: 0.7402
#
# Epoch 00998: val_categorical_accuracy did not improve from 0.77451
# Epoch 999/1000
# 1584/1584 [==============================] - 1s 378us/step - loss: 0.2667 - categorical_accuracy: 0.9135 - val_loss: 1.0626 - val_categorical_accuracy: 0.7402
#
# Epoch 00999: val_categorical_accuracy did not improve from 0.77451
# Epoch 1000/1000
# 1584/1584 [==============================] - 1s 392us/step - loss: 0.2693 - categorical_accuracy: 0.9053 - val_loss: 0.9645 - val_categorical_accuracy: 0.7157
#
# Epoch 01000: val_categorical_accuracy did not improve from 0.77451

# %%
opt=Adam(lr=0.01)
model.load_weights(os.path.join('Checkpoints','weights_model_0_dr03_m1_new.hdf5'))
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
print(model.evaluate(X_train,Y_train))
print(model.evaluate(X_val,Y_val))
print(model.evaluate(X_test,Y_test))
# Out:
# 1584/1584 [==============================] - 2s 1ms/step
# [0.07040292244743217, 0.9728535353535354]
# 204/204 [==============================] - 0s 270us/step
# [0.8921865715700037, 0.7843137254901961]
# 192/192 [==============================] - 0s 264us/step
# [0.88374362885952, 0.7760416666666666]

# %%
Y_probs=model.predict(X_test)

# %%
Y_pred=np.argmax(Y_probs,axis=1)

# %%
Y_test_cat=np.argmax(Y_test,axis=1) #categorical data of Y_test

# %%
target_names = ['backhand', 'forehand', 'bvolley', 'fvolley', 
                   'smash', 'service']

# %%
from sklearn.metrics import classification_report, confusion_matrix
print (classification_report(Y_test_cat, Y_pred, target_names=target_names))
conf_matrix = confusion_matrix(Y_test_cat, Y_pred)
# Out:
#               precision    recall  f1-score   support
#
#     backhand       0.84      0.85      0.85        48
#     forehand       0.79      0.77      0.78        48
#      bvolley       0.80      0.75      0.77        16
#      fvolley       0.83      0.62      0.71        16
#        smash       0.60      0.56      0.58        16
#      service       0.74      0.83      0.78        48
#
#     accuracy                           0.78       192
#    macro avg       0.77      0.73      0.75       192
# weighted avg       0.78      0.78      0.77       192

# %%
import seaborn as sns
import pandas as pd
sns.set(font_scale=1.7)
df_cm = pd.DataFrame(conf_matrix, index = [i for i in target_names],
                  columns = [i for i in target_names])
plt.figure(figsize = (8,5))
ax = sns.heatmap(df_cm, annot=True)
ax.set_xlabel('Predicted Class', fontsize=18, labelpad=20)
ax.set_ylabel('True Class', fontsize=18, rotation=0, labelpad=55)
plt.savefig('confusion_matrix_shallow_0.jpg', bbox_inches = 'tight')
plt.show()
